# %% [markdown]
# ### Data Loading

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score, recall_score,
    roc_auc_score, average_precision_score, confusion_matrix,
    f1_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

from collections import defaultdict, deque
from sklearn.feature_selection import VarianceThreshold

import matplotlib.pyplot as plt
import shap

# %%
df = pd.read_csv("Midfielders.csv")

pd.set_option("display.max_columns", None)

df.head()
df.shape
df.info()
df.isna().mean().sort_values(ascending=False)
df.columns = df.columns.str.strip()
df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 92 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Player                               590 non-null    object
#  1   Season                               590 non-null    object
#  2   Age                                  590 non-null    int64
#  3   Team                                 590 non-null    object
#  4   Goals                                590 non-null    float64
#  5   Assist                               590 non-null    float64
#  6   G+A                                  590 non-null    float64
#  7   Non_penalty_goals                    590 non-null    float64
#  8   Penalty_kicks-made                   590 non-null    float64
#  9   Penalty_kicks_attempted              590 non-null    float64
#  10  Expected_goals                       590 non-null    float64
#  11  Non_penalty_xG                       590 non-null    float64
#  12  Expected_assisted_goals              590 non-null    float64
#  13  xG+xAssisted_G                       590 non-null    float64
#  14  Expected_assists                     590 non-null    float64
#  15  Non_penalty_expGoals+assisted_goals  590 non-null    float64
#  16  Goals-Expected_goals                 590 non-null    float64
#  17  Assists-expGoals_assisted            590 non-null    float64
#  18  Non_penalty_expGoals_perShot         590 non-null    float64
#  19  Shot_/90                             590 non-null    float64
#  20  Goals_per_shot                       590 non-null    float64
#  21  Goals_perShot_onTarget               562 non-null    float64
#  22  Shots_onTarget                       589 non-null    float64
#  23  Shots_onTarget%                      590 non-null    float64
#  24  Passes_completed                     590 non-null    float64
#  25  Passes_attempted                     590 non-null    float64
#  26  Passes_completition%                 590 non-null    float64
#  27  Passes_toShot                        590 non-null    float64
#  28  Passes_into_last3rd                  590 non-null    float64
#  29  Passes_into18yard_box                590 non-null    float64
#  30  Crosses_into18yard_box               590 non-null    float64
#  31  Progressive_passes                   590 non-null    float64
#  32  TotDist_completed_passes             590 non-null    float64
#  33  TotProgressive_passes                590 non-null    float64
#  34  Completed_short_passes               590 non-null    float64
#  35  Attempted_short_passes               590 non-null    float64
#  36  Short_passes_Cmp%                    590 non-null    float64
#  37  Completed_medium_passes              590 non-null    float64
#  38  Attempted_medium_passes              590 non-null    float64
#  39  Medium_pass_Cmp%                     590 non-null    float64
#  40  Completed_long_passes                590 non-null    float64
#  41  Attempted_long_passes                590 non-null    float64
#  42  Long_passes_Cmp%                     590 non-null    float64
#  43  Carries/90                           590 non-null    float64
#  44  TotDist_Carries                      590 non-null    float64
#  45  PrgDist_Carries                      590 non-null    float64
#  46  Carries_10yards_forward              590 non-null    float64
#  47  Carries_into_final_third             590 non-null    float64
#  48  Carries_into18yard_box               590 non-null    float64
#  49  Miscontrols                          590 non-null    float64
#  50  Dispossesd                           590 non-null    float64
#  51  Received                             590 non-null    float64
#  52  Prg_passes_received                  590 non-null    float64
#  53  Goal_creating_actions                590 non-null    float64
#  54  PassLive_lead_goal                   590 non-null    float64
#  55  Shot_creating_actions                590 non-null    float64
#  56  PassLive_lead_shot_attempt           590 non-null    float64
#  57  Aerials_Won%                         590 non-null    float64
#  58  Yellow_cards                         590 non-null    float64
#  59  Red_cards                            590 non-null    float64
#  60  Fouls_committed                      590 non-null    float64
#  61  Fouls_drawn                          590 non-null    float64
#  62  Tackles_on_players                   590 non-null    float64
#  63  Tackles_won                          590 non-null    float64
#  64  Tackles_on_dribblers                 590 non-null    float64
#  65  Lost_challange_drib_player           590 non-null    float64
#  66  Blocking_ball                        590 non-null    float64
#  67  Blocking_shots                       590 non-null    float64
#  68  Blocking_pass                        590 non-null    float64
#  69  Interceptions                        590 non-null    float64
#  70  Tackles_+Interc                      590 non-null    float64
#  71  Clearences                           590 non-null    float64
#  72  Mistakes_leadto_shot                 590 non-null    float64
#  73  Live_ball_passes                     590 non-null    float64
#  74  Dead_ball_pass                       590 non-null    float64
#  75  Passes_freeKick                      590 non-null    float64
#  76  Passes_behind_defenders              590 non-null    float64
#  77  Swing_passes                         590 non-null    float64
#  78  Crosses                              590 non-null    float64
#  79  Corner_kikcs                         590 non-null    float64
#  80  Offsides                             590 non-null    float64
#  81  Succ_Takes_on%                       590 non-null    float64
#  82  Tkld_During_Take_On%                 590 non-null    float64
#  83  Touches/90                           590 non-null    float64
#  84  Touches_Def_Pen                      590 non-null    float64
#  85  Touches_Def 3rd                      590 non-null    float64
#  86  Touches_Mid 3rd                      590 non-null    float64
#  87  Touches_Att 3rd                      590 non-null    float64
#  88  Touches_Att Pen                      590 non-null    float64
#  89  Touches_Live                         590 non-null    float64
#  90  Role                                 590 non-null    object
#  91  Tier_league                          590 non-null    int64
# dtypes: float64(86), int64(2), object(4)
# memory usage: 424.2+ KB

# %%
df["Role"].value_counts()
# Out:
# Role
# CM    161
# DM    147
# RW     94
# LW     93
# AM     81
# RM     12
# LM      2
# Name: count, dtype: int64

# %%
# Splitting the dataset

OFFENSIVE_MID_ROLES = [
    "AM",
    "LW",
    "RW",
    "Wide Midfielder"
]

DEFENSIVE_MID_ROLES = [
    "DM",
    "CM",
    "RM",
    "LM",
]

# %%
def map_midfield_group(role):
    if role in OFFENSIVE_MID_ROLES:
        return "offensive_mid"
    elif role in DEFENSIVE_MID_ROLES:
        return "defensive_mid"
    else:
        return np.nan

df["mid_group"] = df["Role"].apply(map_midfield_group)

df["mid_group"].value_counts(dropna=False)
# Out:
# mid_group
# defensive_mid    322
# offensive_mid    268
# Name: count, dtype: int64

# %%
off_mid = df[df["mid_group"] == "offensive_mid"].copy()
def_mid = df[df["mid_group"] == "defensive_mid"].copy()

print("off_mid shape:", off_mid.shape)
print("def_mid shape:", def_mid.shape)
# Out:
# off_mid shape: (268, 93)
# def_mid shape: (322, 93)

# %%
off_mid.to_csv("OffensiveMidfielders.csv", index=False)
def_mid.to_csv("DefensiveMidfielders.csv", index=False)

# %% [markdown]
# ### EDA and Feature Scraping

# %%
print("\nOFF MID Tier_league balance:")
print(off_mid["Tier_league"].value_counts(dropna=False))
print(off_mid["Tier_league"].value_counts(normalize=True, dropna=False))

print("\nDEF MID Tier_league balance:")
print(def_mid["Tier_league"].value_counts(dropna=False))
print(def_mid["Tier_league"].value_counts(normalize=True, dropna=False))
# Out:
# OFF MID Tier_league balance:
# Tier_league
# 1    131
# 0     72
# 2     65
# Name: count, dtype: int64
# Tier_league
# 1    0.488806
# 0    0.268657
# 2    0.242537
# Name: proportion, dtype: float64
#
# DEF MID Tier_league balance:
# Tier_league
# 1    153
# 0     93
# 2     76
# Name: count, dtype: int64
# Tier_league
# 1    0.475155
# 0    0.288820
# 2    0.236025
# Name: proportion, dtype: float64

# %%
# Convert Tier_league to binary: Tier 2 = 1, others = 0

off_mid["Tier_league"] = (off_mid["Tier_league"] == 2).astype(int)
def_mid["Tier_league"] = (def_mid["Tier_league"] == 2).astype(int)

# Verify
print("\nOFF MID Tier_league (binary):")
print(off_mid["Tier_league"].value_counts())
print(off_mid["Tier_league"].value_counts(normalize=True))

print("\nDEF MID Tier_league (binary):")
print(def_mid["Tier_league"].value_counts())
print(def_mid["Tier_league"].value_counts(normalize=True))
# Out:
# OFF MID Tier_league (binary):
# Tier_league
# 0    203
# 1     65
# Name: count, dtype: int64
# Tier_league
# 0    0.757463
# 1    0.242537
# Name: proportion, dtype: float64
#
# DEF MID Tier_league (binary):
# Tier_league
# 0    246
# 1     76
# Name: count, dtype: int64
# Tier_league
# 0    0.763975
# 1    0.236025
# Name: proportion, dtype: float64

# %%
def missing_report(df_in, name, top_n=20):
    miss = df_in.isna().mean().sort_values(ascending=False)
    miss = miss[miss > 0]
    print(f"\n{name} missingness (top {top_n}):")
    print(miss.head(top_n))

missing_report(off_mid, "OFF MID")
missing_report(def_mid, "DEF MID")
# Out:
# OFF MID missingness (top 20):
# Shots_onTarget            0.003731
# Goals_perShot_onTarget    0.003731
# dtype: float64
#
# DEF MID missingness (top 20):
# Goals_perShot_onTarget    0.083851
# dtype: float64

# %%
off_mid.dtypes.value_counts()
# Out:
# float64    86
# object      5
# int64       2
# Name: count, dtype: int64

# %%
off_mid.select_dtypes(exclude=["number"]).columns.tolist()
# Out:
# ['Player', 'Season', 'Team', 'Role', 'mid_group']

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]

# Drop mid_group
off_mid = off_mid.drop(columns=["mid_group"])
def_mid = def_mid.drop(columns=["mid_group"])

# %% [markdown]
# Offensive Midfielders feature inspection

# %%
FEATURE_COLS = [c for c in off_mid.columns 
                if c not in ID_COLS + ["Tier_league"]]

# %%
zero_frac = (off_mid[FEATURE_COLS] == 0).mean().sort_values(ascending=False)
zero_frac.head(20)
# Out:
# Red_cards                       0.895522
# Mistakes_leadto_shot            0.873134
# Penalty_kicks-made              0.865672
# Penalty_kicks_attempted         0.832090
# Blocking_shots                  0.477612
# Assists-expGoals_assisted       0.455224
# Goals-Expected_goals            0.432836
# Passes_behind_defenders         0.212687
# Corner_kikcs                    0.190299
# Offsides                        0.167910
# Non_penalty_goals               0.130597
# Yellow_cards                    0.126866
# Goals                           0.123134
# Swing_passes                    0.119403
# Assist                          0.119403
# Goals_perShot_onTarget          0.115672
# Passes_freeKick                 0.111940
# Non_penalty_expGoals_perShot    0.104478
# Crosses_into18yard_box          0.097015
# Goals_per_shot                  0.089552
# dtype: float64

# %%
FEATURE_COLS = [c for c in off_mid.columns 
                if c not in ID_COLS + ["Tier_league"]]

variances = off_mid[FEATURE_COLS].var().sort_values()

variances.head(20)
# Out:
# Mistakes_leadto_shot                   0.001112
# Red_cards                              0.001223
# Penalty_kicks-made                     0.002599
# Penalty_kicks_attempted                0.003678
# Non_penalty_expGoals_perShot           0.004712
# Blocking_shots                         0.005697
# Expected_assists                       0.006101
# Expected_assisted_goals                0.008428
# Assists-expGoals_assisted              0.009402
# Goals-Expected_goals                   0.009729
# Non_penalty_xG                         0.010001
# Yellow_cards                           0.011963
# Assist                                 0.015588
# Expected_goals                         0.016720
# Non_penalty_goals                      0.019806
# Non_penalty_expGoals+assisted_goals    0.021926
# Goals                                  0.026795
# Goals_perShot_onTarget                 0.026974
# xG+xAssisted_G                         0.030858
# PassLive_lead_goal                     0.036887
# dtype: float64

# %%
DROP_COLS_OFF_MID = [
    "Mistakes_leadto_shot",
    "Red_cards",
    "Penalty_kicks-made",
    "Penalty_kicks_attempted",
    "Yellow_cards",
    "Blocking_shots"
]
off_mid = off_mid.drop(columns=DROP_COLS_OFF_MID)

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET_COL = "Tier_league"

FEATURE_COLS_OFF = [
    c for c in off_mid.columns
    if c not in ID_COLS + [TARGET_COL]
]

print("OFF MID – number of features:", len(FEATURE_COLS_OFF))
FEATURE_COLS_OFF
# Out:
# OFF MID – number of features: 81
# ['Age',
#  'Goals',
#  'Assist',
#  'G+A',
#  'Non_penalty_goals',
#  'Expected_goals',
#  'Non_penalty_xG',
#  'Expected_assisted_goals',
#  'xG+xAssisted_G',
#  'Expected_assists',
#  'Non_penalty_expGoals+assisted_goals',
#  'Goals-Expected_goals',
#  'Assists-expGoals_assisted',
#  'Non_penalty_expGoals_perShot',
#  'Shot_/90',
#  'Goals_per_shot',
#  'Goals_perShot_onTarget',
#  'Shots_onTarget',
#  'Shots_onTarget%',
#  'Passes_completed',
#  'Passes_attempted',
#  'Passes_completition%',
#  'Passes_toShot',
#  'Passes_into_last3rd',
#  'Passes_into18yard_box',
#  'Crosses_into18yard_box',
#  'Progressive_passes',
#  'TotDist_completed_passes',
#  'TotProgressive_passes',
#  'Completed_short_passes',
#  'Attempted_short_passes',
#  'Short_passes_Cmp%',
#  'Completed_medium_passes',
#  'Attempted_medium_passes',
#  'Medium_pass_Cmp%',
#  'Completed_long_passes',
#  'Attempted_long_passes',
#  'Long_passes_Cmp%',
#  'Carries/90',
#  'TotDist_Carries',
#  'PrgDist_Carries',
#  'Carries_10yards_forward',
#  'Carries_into_final_third',
#  'Carries_into18yard_box',
#  'Miscontrols',
#  'Dispossesd',
#  'Received',
#  'Prg_passes_received',
#  'Goal_creating_actions',
#  'PassLive_lead_goal',
#  'Shot_creating_actions',
#  'PassLive_lead_shot_attempt',
#  'Aerials_Won%',
#  'Fouls_committed',
#  'Fouls_drawn',
#  'Tackles_on_players',
#  'Tackles_won',
#  'Tackles_on_dribblers',
#  'Lost_challange_drib_player',
#  'Blocking_ball',
#  'Blocking_pass',
#  'Interceptions',
#  'Tackles_+Interc',
#  'Clearences',
#  'Live_ball_passes',
#  'Dead_ball_pass',
#  'Passes_freeKick',
#  'Passes_behind_defenders',
#  'Swing_passes',
#  'Crosses',
#  'Corner_kikcs',
#  'Offsides',
#  'Succ_Takes_on%',
#  'Tkld_During_Take_On%',
#  'Touches/90',
#  'Touches_Def_Pen',
#  'Touches_Def_3rd',
#  'Touches_Mid_3rd',
#  'Touches_Att_3rd',
#  'Touches_Att_Pen',
#  'Touches_Live']

# %% [markdown]
# Def_mid feature inspection

# %%
FEATURE_COLS = [c for c in def_mid.columns 
                if c not in ID_COLS + ["Tier_league"]]

# %%
zero_frac = (def_mid[FEATURE_COLS] == 0).mean().sort_values(ascending=False)
zero_frac.head(20)
# Out:
# Penalty_kicks-made           0.962733
# Penalty_kicks_attempted      0.953416
# Red_cards                    0.897516
# Offsides                     0.692547
# Mistakes_leadto_shot         0.683230
# Assists-expGoals_assisted    0.680124
# Goals-Expected_goals         0.639752
# Corner_kikcs                 0.568323
# Non_penalty_goals            0.568323
# Goals                        0.552795
# Assist                       0.453416
# Expected_assists             0.431677
# Goals_per_shot               0.419255
# Non_penalty_xG               0.413043
# Crosses_into18yard_box       0.409938
# Expected_goals               0.403727
# Expected_assisted_goals      0.397516
# Goals_perShot_onTarget       0.350932
# Passes_behind_defenders      0.295031
# G+A                          0.263975
# dtype: float64

# %%
FEATURE_COLS = [c for c in def_mid.columns 
                if c not in ID_COLS + ["Tier_league"]]

variances = def_mid[FEATURE_COLS].var().sort_values()

variances.head(20)
# Out:
# Red_cards                              0.000923
# Penalty_kicks-made                     0.001028
# Penalty_kicks_attempted                0.001475
# Non_penalty_expGoals_perShot           0.002046
# Mistakes_leadto_shot                   0.003450
# Non_penalty_xG                         0.003908
# Assists-expGoals_assisted              0.004236
# Goals-Expected_goals                   0.004240
# Expected_assists                       0.004292
# Expected_goals                         0.004775
# Expected_assisted_goals                0.004987
# Non_penalty_goals                      0.005639
# Goals                                  0.006885
# Non_penalty_expGoals+assisted_goals    0.008651
# Assist                                 0.008657
# Offsides                               0.008953
# xG+xAssisted_G                         0.010047
# PassLive_lead_goal                     0.016274
# Yellow_cards                           0.016483
# G+A                                    0.016982
# dtype: float64

# %%
DROP_COLS_DEF_MID = [
    "Penalty_kicks-made",
    "Penalty_kicks_attempted",
    "Red_cards",
    "Mistakes_leadto_shot",
    "Offsides",
    "Goals-Expected_goals",
    "Assists-expGoals_assisted",
    "Yellow_cards"
]
def_mid = def_mid.drop(columns=DROP_COLS_DEF_MID)

# %%
FEATURE_COLS_DEF = [
    c for c in def_mid.columns
    if c not in ID_COLS + [TARGET_COL]
]

print("DEF MID – number of features:", len(FEATURE_COLS_DEF))
FEATURE_COLS_DEF
# Out:
# DEF MID – number of features: 79
# ['Age',
#  'Goals',
#  'Assist',
#  'G+A',
#  'Non_penalty_goals',
#  'Expected_goals',
#  'Non_penalty_xG',
#  'Expected_assisted_goals',
#  'xG+xAssisted_G',
#  'Expected_assists',
#  'Non_penalty_expGoals+assisted_goals',
#  'Non_penalty_expGoals_perShot',
#  'Shot_/90',
#  'Goals_per_shot',
#  'Goals_perShot_onTarget',
#  'Shots_onTarget',
#  'Shots_onTarget%',
#  'Passes_completed',
#  'Passes_attempted',
#  'Passes_completition%',
#  'Passes_toShot',
#  'Passes_into_last3rd',
#  'Passes_into18yard_box',
#  'Crosses_into18yard_box',
#  'Progressive_passes',
#  'TotDist_completed_passes',
#  'TotProgressive_passes',
#  'Completed_short_passes',
#  'Attempted_short_passes',
#  'Short_passes_Cmp%',
#  'Completed_medium_passes',
#  'Attempted_medium_passes',
#  'Medium_pass_Cmp%',
#  'Completed_long_passes',
#  'Attempted_long_passes',
#  'Long_passes_Cmp%',
#  'Carries/90',
#  'TotDist_Carries',
#  'PrgDist_Carries',
#  'Carries_10yards_forward',
#  'Carries_into_final_third',
#  'Carries_into18yard_box',
#  'Miscontrols',
#  'Dispossesd',
#  'Received',
#  'Prg_passes_received',
#  'Goal_creating_actions',
#  'PassLive_lead_goal',
#  'Shot_creating_actions',
#  'PassLive_lead_shot_attempt',
#  'Aerials_Won%',
#  'Fouls_committed',
#  'Fouls_drawn',
#  'Tackles_on_players',
#  'Tackles_won',
#  'Tackles_on_dribblers',
#  'Lost_challange_drib_player',
#  'Blocking_ball',
#  'Blocking_shots',
#  'Blocking_pass',
#  'Interceptions',
#  'Tackles_+Interc',
#  'Clearences',
#  'Live_ball_passes',
#  'Dead_ball_pass',
#  'Passes_freeKick',
#  'Passes_behind_defenders',
#  'Swing_passes',
#  'Crosses',
#  'Corner_kikcs',
#  'Succ_Takes_on%',
#  'Tkld_During_Take_On%',
#  'Touches/90',
#  'Touches_Def_Pen',
#  'Touches_Def_3rd',
#  'Touches_Mid_3rd',
#  'Touches_Att_3rd',
#  'Touches_Att_Pen',
#  'Touches_Live']

# %%
# Flags for security of ratio/0 events
off_mid = off_mid.copy()

off_mid["has_shot"] = (off_mid["Shot_/90"] > 0).astype(int)
off_mid["has_sot"] = (off_mid["Shots_onTarget"] > 0).astype(int)
off_mid["has_goal"] = (off_mid["Goals"] > 0).astype(int)
off_mid["has_assist"] = (off_mid["Assist"] > 0).astype(int)
off_mid["has_key_pass"] = (off_mid["Passes_toShot"] > 0).astype(int)
off_mid["has_sca"] = (off_mid["Shot_creating_actions"] > 0).astype(int)
off_mid["has_gca"] = (off_mid["Goal_creating_actions"] > 0).astype(int)
off_mid["has_carry_final_third"] = (off_mid["Carries_into_final_third"] > 0).astype(int)
off_mid["has_carry_box"] = (off_mid["Carries_into18yard_box"] > 0).astype(int)

def_mid = def_mid.copy()

def_mid["has_shot"] = (def_mid["Shot_/90"] > 0).astype(int)
def_mid["has_goal"] = (def_mid["Goals"] > 0).astype(int)
def_mid["has_assist"] = (def_mid["Assist"] > 0).astype(int)
def_mid["has_key_pass"] = (def_mid["Passes_toShot"] > 0).astype(int)
def_mid["has_tackle"] = (def_mid["Tackles_won"] > 0).astype(int)
def_mid["has_interception"] = (def_mid["Interceptions"] > 0).astype(int)
def_mid["has_block"] = (
    (def_mid["Blocking_shots"] + def_mid["Blocking_pass"]) > 0
).astype(int)

# %%
flag_cols_off = [
    "has_shot", "has_sot", "has_goal", "has_assist",
    "has_key_pass", "has_sca", "has_gca",
    "has_carry_final_third", "has_carry_box"
]

off_mid[flag_cols_off].mean().sort_values(ascending=False)
# Out:
# has_shot                 1.000000
# has_key_pass             1.000000
# has_carry_box            1.000000
# has_carry_final_third    1.000000
# has_gca                  0.981343
# has_sca                  0.981343
# has_sot                  0.966418
# has_assist               0.880597
# has_goal                 0.876866
# dtype: float64

# %%
flag_cols_def = [
    "has_shot", "has_goal", "has_assist",
    "has_key_pass", "has_tackle",
    "has_interception", "has_block"
]

def_mid[flag_cols_def].mean().sort_values(ascending=False)
# Out:
# has_shot            1.000000
# has_tackle          1.000000
# has_key_pass        1.000000
# has_interception    1.000000
# has_block           1.000000
# has_assist          0.546584
# has_goal            0.447205
# dtype: float64

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET = "Tier_league"

FEATURES_OFF = [
    c for c in off_mid.columns
    if c not in ID_COLS + [TARGET]
]

FEATURES_OFF = [
    c for c in FEATURES_OFF
    if off_mid[c].std() != 0
]

FEATURES_DEF = [
    c for c in def_mid.columns
    if c not in ID_COLS + [TARGET]
]

FEATURES_DEF = [
    c for c in FEATURES_DEF
    if def_mid[c].std() != 0
]

# %%
corr_off = (
    off_mid[FEATURES_OFF]
    .corrwith(off_mid[TARGET])
    .sort_values(key=lambda x: x.abs(), ascending=False)
)

corr_off.head(20)
# Out:
# PassLive_lead_goal                     0.448784
# G+A                                    0.412894
# Non_penalty_expGoals+assisted_goals    0.388644
# xG+xAssisted_G                         0.380381
# Passes_behind_defenders                0.372528
# Assist                                 0.329871
# Touches_Att_Pen                        0.328326
# Attempted_short_passes                 0.316311
# Goals                                  0.308043
# Live_ball_passes                       0.305999
# Expected_assisted_goals                0.302099
# Expected_goals                         0.293486
# Passes_completed                       0.278900
# Touches/90                             0.278220
# Touches_Live                           0.277729
# Expected_assists                       0.275939
# Non_penalty_goals                      0.270813
# Touches_Att_3rd                        0.267972
# Assists-expGoals_assisted              0.261921
# Passes_attempted                       0.259710
# dtype: float64

# %%
corr_def = (
    def_mid[FEATURES_DEF]
    .corrwith(def_mid[TARGET])
    .sort_values(key=lambda x: x.abs(), ascending=False)
)

corr_def.head(20)
# Out:
# TotDist_Carries             0.455914
# Touches_Live                0.451628
# Touches/90                  0.451453
# Touches_Mid_3rd             0.451078
# Attempted_short_passes      0.447112
# Live_ball_passes            0.443778
# Passes_attempted            0.441415
# Received                    0.440859
# Passes_completed            0.434829
# Carries/90                  0.412303
# Passes_into_last3rd         0.408865
# Progressive_passes          0.392474
# TotDist_completed_passes    0.382339
# Attempted_medium_passes     0.367526
# PrgDist_Carries             0.354373
# Passes_behind_defenders     0.328699
# PassLive_lead_goal          0.290448
# Shot_creating_actions       0.247818
# Passes_completition%        0.237317
# Long_passes_Cmp%            0.228700
# dtype: float64

# %%
DROP_FLAGS_OFF = [
    "has_shot",
    "has_key_pass",
    "has_carry_box",
    "has_carry_final_third",
    "has_sca",
    "has_gca"
]

off_mid = off_mid.drop(columns=DROP_FLAGS_OFF)

# %%
DROP_FLAGS_DEF = [
    "has_shot",
    "has_tackle",
    "has_interception",
    "has_block",
    "has_key_pass"
]

def_mid = def_mid.drop(columns=DROP_FLAGS_DEF)

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET = "Tier_league"

NUM_FEATURES_OFF = [
    c for c in off_mid.columns
    if c not in ID_COLS + [TARGET]
]

NUM_FEATURES_DEF = [
    c for c in def_mid.columns
    if c not in ID_COLS + [TARGET]
]

corr_matrix_off = off_mid[NUM_FEATURES_OFF].corr().abs()
corr_matrix_def = def_mid[NUM_FEATURES_DEF].corr().abs()

# %%
# High correlation analysis

def get_high_corr_pairs(corr_matrix, threshold=0.9):
    upper = corr_matrix.where(
        np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
    )
    return (
        upper.stack()
        .reset_index()
        .rename(columns={"level_0": "f1", "level_1": "f2", 0: "corr"})
        .query("corr >= @threshold")
        .sort_values("corr", ascending=False)
    )

high_corr_off = get_high_corr_pairs(corr_matrix_off, 0.9)
high_corr_def = get_high_corr_pairs(corr_matrix_def, 0.9)

high_corr_off.head(30)
# Out:
#                             f1                                   f2      corr
# 3446                Touches/90                         Touches_Live  0.999985
# 3420            Succ_Takes_on%                 Tkld_During_Take_On%  0.999747
# 1607             Passes_toShot                Completed_long_passes  0.998027
# 1604             Passes_toShot              Completed_medium_passes  0.993483
# 2162   Completed_medium_passes                Completed_long_passes  0.993117
# 2110         Short_passes_Cmp%                     Medium_pass_Cmp%  0.984599
# 1603             Passes_toShot                    Short_passes_Cmp%  0.980023
# 2111         Short_passes_Cmp%                Completed_long_passes  0.978411
# 3186             Blocking_ball                        Blocking_pass  0.977797
# 2108         Short_passes_Cmp%              Completed_medium_passes  0.970426
# 1606             Passes_toShot                     Medium_pass_Cmp%  0.968056
# 637             xG+xAssisted_G  Non_penalty_expGoals+assisted_goals  0.967625
# 2261          Medium_pass_Cmp%                Completed_long_passes  0.963729
# 3311          Live_ball_passes                         Touches_Live  0.959907
# 3305          Live_ball_passes                           Touches/90  0.959393
# 2588   Carries_10yards_forward                  Prg_passes_received  0.959301
# 1908  TotDist_completed_passes                             Received  0.957290
# 1545      Passes_completition%                     Medium_pass_Cmp%  0.954856
# 85                       Goals                    Non_penalty_goals  0.952877
# 2175   Completed_medium_passes                Goal_creating_actions  0.952118
# 1620             Passes_toShot                Goal_creating_actions  0.950630
# 2161   Completed_medium_passes                     Medium_pass_Cmp%  0.949086
# 1946     TotProgressive_passes               Completed_short_passes  0.945908
# 1482          Passes_attempted              Attempted_medium_passes  0.944910
# 1613             Passes_toShot              Carries_10yards_forward  0.944853
# 1542      Passes_completition%                    Short_passes_Cmp%  0.944845
# 2263          Medium_pass_Cmp%                     Long_passes_Cmp%  0.943083
# 2322     Completed_long_passes                Goal_creating_actions  0.942425
# 2168   Completed_medium_passes              Carries_10yards_forward  0.941087
# 2315     Completed_long_passes              Carries_10yards_forward  0.940768

# %%
high_corr_def.head(30)
# Out:
#                            f1                                   f2      corr
# 3209               Touches/90                         Touches_Live  0.999997
# 3185           Succ_Takes_on%                 Tkld_During_Take_On%  0.999926
# 1422            Passes_toShot                Completed_long_passes  0.991889
# 1331         Passes_attempted                     Live_ball_passes  0.987324
# 1346         Passes_attempted                         Touches_Live  0.983169
# 1340         Passes_attempted                           Touches/90  0.983138
# 3101         Live_ball_passes                         Touches_Live  0.982139
# 3095         Live_ball_passes                           Touches/90  0.982084
# 3098         Live_ball_passes                      Touches_Mid_3rd  0.963477
# 1343         Passes_attempted                      Touches_Mid_3rd  0.958135
# 1916        Short_passes_Cmp%                     Medium_pass_Cmp%  0.957386
# 613            xG+xAssisted_G  Non_penalty_expGoals+assisted_goals  0.954002
# 2384  Carries_10yards_forward                  Prg_passes_received  0.952449
# 1269         Passes_completed                     Live_ball_passes  0.949089
# 1418            Passes_toShot                    Short_passes_Cmp%  0.947528
# 1224         Passes_completed                     Passes_attempted  0.947307
# 3227          Touches_Mid_3rd                         Touches_Live  0.945571
# 3206               Touches/90                      Touches_Mid_3rd  0.945505
# 1967  Completed_medium_passes                Completed_long_passes  0.943531
# 1312         Passes_attempted                             Received  0.936059
# 1284         Passes_completed                         Touches_Live  0.932353
# 1278         Passes_completed                           Touches/90  0.932338
# 2862       Tackles_on_players                          Tackles_won  0.928314
# 1917        Short_passes_Cmp%                Completed_long_passes  0.925103
# 1361     Passes_completition%                     Medium_pass_Cmp%  0.923469
# 1905   Attempted_short_passes                           Touches/90  0.922756
# 1911   Attempted_short_passes                         Touches_Live  0.922748
# 1296         Passes_attempted               Attempted_short_passes  0.919623
# 1896   Attempted_short_passes                     Live_ball_passes  0.918635
# 1419            Passes_toShot              Completed_medium_passes  0.918392

# %%
# Correltion clusters analysis

def build_corr_clusters(pairs_df):
    graph = defaultdict(set)
    for f1, f2 in pairs_df[["f1", "f2"]].values:
        graph[f1].add(f2)
        graph[f2].add(f1)

    seen = set()
    clusters = []
    for node in graph:
        if node in seen:
            continue
        q = deque([node])
        comp = set()
        seen.add(node)
        while q:
            u = q.popleft()
            comp.add(u)
            for v in graph[u]:
                if v not in seen:
                    seen.add(v)
                    q.append(v)
        clusters.append(sorted(comp))
    clusters = sorted(clusters, key=len, reverse=True)
    return clusters

clusters_off = build_corr_clusters(high_corr_off)
clusters_def = build_corr_clusters(high_corr_def)

clusters_off[:10],
# Out:
# ([['Carries_10yards_forward',
#    'Completed_long_passes',
#    'Completed_medium_passes',
#    'Completed_short_passes',
#    'Goal_creating_actions',
#    'Goals_per_shot',
#    'Long_passes_Cmp%',
#    'Medium_pass_Cmp%',
#    'Passes_completition%',
#    'Passes_toShot',
#    'Prg_passes_received',
#    'Progressive_passes',
#    'Received',
#    'Short_passes_Cmp%',
#    'TotDist_Carries',
#    'TotDist_completed_passes',
#    'TotProgressive_passes'],
#   ['Attempted_medium_passes',
#    'Attempted_short_passes',
#    'Live_ball_passes',
#    'Passes_attempted',
#    'Touches/90',
#    'Touches_Live',
#    'Touches_Mid_3rd'],
#   ['Tackles_+Interc', 'Tackles_on_players', 'Tackles_won'],
#   ['Succ_Takes_on%', 'Tkld_During_Take_On%'],
#   ['Blocking_ball', 'Blocking_pass'],
#   ['Non_penalty_expGoals+assisted_goals', 'xG+xAssisted_G'],
#   ['Goals', 'Non_penalty_goals'],
#   ['Expected_goals', 'Non_penalty_xG']],)

# %%
clusters_def[:10]
# Out:
# [['Attempted_medium_passes',
#   'Attempted_short_passes',
#   'Live_ball_passes',
#   'Passes_attempted',
#   'Passes_completed',
#   'Received',
#   'Touches/90',
#   'Touches_Live',
#   'Touches_Mid_3rd'],
#  ['Completed_long_passes',
#   'Completed_medium_passes',
#   'Completed_short_passes',
#   'Medium_pass_Cmp%',
#   'Passes_completition%',
#   'Passes_toShot',
#   'Short_passes_Cmp%'],
#  ['Carries_10yards_forward', 'Goal_creating_actions', 'Prg_passes_received'],
#  ['Succ_Takes_on%', 'Tkld_During_Take_On%'],
#  ['Non_penalty_expGoals+assisted_goals', 'xG+xAssisted_G'],
#  ['Tackles_on_players', 'Tackles_won'],
#  ['Goals', 'Non_penalty_goals'],
#  ['Passes_into_last3rd', 'Progressive_passes']]

# %%
DROP_OFF_PASS_VOLUME = [
    "Attempted_short_passes",
    "Attempted_medium_passes",
    "Live_ball_passes",
    "Touches/90",
    "Touches_Live",
    "Received"
]
DROP_OFF_COMPLETED_PASSES = [
    "Completed_short_passes",
    "Completed_medium_passes",
    "Completed_long_passes"
]
DROP_OFF_TOTALS = [
    "TotDist_Carries",
    "TotDist_completed_passes",
    "TotProgressive_passes",
    "Prg_passes_received"
]
DROP_OFF_PASS_PCT = [
    "Short_passes_Cmp%",
    "Medium_pass_Cmp%",
    "Long_passes_Cmp%"
]
DROP_OFF_PROGRESSIVE = [
    "Passes_into_last3rd"
]
DROP_OFF_TACKLES = [
    "Tackles_on_players",
    "Tackles_won"
]
DROP_OFF_TAKEONS = [
    "Tkld_During_Take_On%"
]
DROP_OFF_COMPOSITES = [
    "G+A",
    "xG+xAssisted_G",
    "Non_penalty_expGoals+assisted_goals"
]
DROP_OFF_GOALS_XG = [
    "Goals",
    "Expected_goals"
]
DROP_OFF = (
    DROP_OFF_PASS_VOLUME
    + DROP_OFF_COMPLETED_PASSES
    + DROP_OFF_TOTALS
    + DROP_OFF_PASS_PCT
    + DROP_OFF_PROGRESSIVE
    + DROP_OFF_TACKLES
    + DROP_OFF_TAKEONS
    + DROP_OFF_COMPOSITES
    + DROP_OFF_GOALS_XG
)

off_mid = off_mid.drop(columns=[c for c in DROP_OFF if c in off_mid.columns])

# %%
DROP_DEF_PASS_VOLUME = [
    "Attempted_short_passes",
    "Attempted_medium_passes",
    "Live_ball_passes",
    "Touches/90",
    "Touches_Live",
    "Received"
]
DROP_DEF_COMPLETED_PASSES = [
    "Completed_short_passes",
    "Completed_medium_passes",
    "Completed_long_passes"
]
DROP_DEF_PASS_PCT = [
    "Short_passes_Cmp%",
    "Medium_pass_Cmp%"
]
DROP_DEF_TACKLES = [
    "Tackles_on_players"
]
DROP_DEF_PROGRESSIVE = [
    "Passes_into_last3rd"
]
DROP_DEF_TAKEONS = [
    "Tkld_During_Take_On%"
]
DROP_DEF_COMPOSITES = [
    "xG+xAssisted_G",
    "Non_penalty_expGoals+assisted_goals"
]
DROP_DEF_GOALS_XG = [
    "Goals",
    "Expected_goals"
]
DROP_DEF = (
    DROP_DEF_PASS_VOLUME
    + DROP_DEF_COMPLETED_PASSES
    + DROP_DEF_PASS_PCT
    + DROP_DEF_TACKLES
    + DROP_DEF_PROGRESSIVE
    + DROP_DEF_TAKEONS
    + DROP_DEF_COMPOSITES
    + DROP_DEF_GOALS_XG
)

def_mid = def_mid.drop(columns=[c for c in DROP_DEF if c in def_mid.columns])

# %%
print("OFF MID features:", off_mid.shape[1] - len(ID_COLS) - 1)
print("DEF MID features:", def_mid.shape[1] - len(ID_COLS) - 1)
# Out:
# OFF MID features: 59
# DEF MID features: 63

# %%
def get_high_corr_pairs_df(df_in, id_cols, target_col, threshold=0.9):
   
    feat_cols = [c for c in df_in.columns if c not in id_cols + [target_col]]
    X = df_in[feat_cols].select_dtypes(include="number")

    corr_matrix = X.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

    pairs = (
        upper.stack()
        .reset_index()
        .rename(columns={"level_0": "f1", "level_1": "f2", 0: "corr"})
    )

    
    pairs["corr"] = pd.to_numeric(pairs["corr"], errors="coerce")
    pairs = pairs[pairs["corr"].ge(threshold)].sort_values("corr", ascending=False)

    return pairs

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET = "Tier_league"

high_pairs_off = get_high_corr_pairs_df(off_mid, ID_COLS, TARGET, threshold=0.9)
high_pairs_def = get_high_corr_pairs_df(def_mid, ID_COLS, TARGET, threshold=0.9)

print("OFF high corr pairs:", len(high_pairs_off))
print("DEF high corr pairs:", len(high_pairs_def))

high_pairs_off.head(20), high_pairs_def.head(20)
# Out:
# OFF high corr pairs: 7
# DEF high corr pairs: 5
# (                           f1                       f2      corr
#  1501            Blocking_ball            Blocking_pass  0.977797
#  861             Passes_toShot    Goal_creating_actions  0.950630
#  856             Passes_toShot  Carries_10yards_forward  0.944853
#  1120  Carries_10yards_forward    Goal_creating_actions  0.926076
#  548            Goals_per_shot  Carries_10yards_forward  0.908333
#  541            Goals_per_shot            Passes_toShot  0.907892
#  553            Goals_per_shot    Goal_creating_actions  0.900503,
#                             f1                     f2      corr
#  820          Passes_attempted        Touches_Mid_3rd  0.958135
#  1327  Carries_10yards_forward    Prg_passes_received  0.952449
#  728          Passes_completed       Passes_attempted  0.947307
#  1328  Carries_10yards_forward  Goal_creating_actions  0.914178
#  772          Passes_completed        Touches_Mid_3rd  0.908786)

# %%
off_mid = off_mid.drop(columns=["Blocking_pass"])
off_mid = off_mid.drop(columns=["Goals_per_shot"])
def_mid = def_mid.drop(columns=["Touches_Mid_3rd"])
def_mid = def_mid.drop(columns=["Passes_completed"])
def_mid = def_mid.drop(columns=["Prg_passes_received"])

# %%
high_pairs_off2 = get_high_corr_pairs_df(off_mid, ID_COLS, TARGET, threshold=0.9)
high_pairs_def2 = get_high_corr_pairs_df(def_mid, ID_COLS, TARGET, threshold=0.9)

print("OFF remaining pairs:", len(high_pairs_off2))
print("DEF remaining pairs:", len(high_pairs_def2))

high_pairs_off2, high_pairs_def2
# Out:
# OFF remaining pairs: 3
# DEF remaining pairs: 1
# (                           f1                       f2      corr
#  787             Passes_toShot    Goal_creating_actions  0.950630
#  782             Passes_toShot  Carries_10yards_forward  0.944853
#  1039  Carries_10yards_forward    Goal_creating_actions  0.926076,
#                             f1                     f2      corr
#  1213  Carries_10yards_forward  Goal_creating_actions  0.914178)

# %%
off_mid = off_mid.drop(columns=["Passes_toShot"])

# %%
FEATURES_OFF = [
    c for c in off_mid.columns
    if c not in ID_COLS + [TARGET]
]

FEATURES_DEF = [
    c for c in def_mid.columns
    if c not in ID_COLS + [TARGET]
]

len(FEATURES_OFF), len(FEATURES_DEF)
# Out:
# (56, 60)

# %%
off_mid[FEATURES_OFF].describe().T
# Out:
#                               count        mean        std    min     25%  \
# Age                           268.0   23.231343   2.537846  18.00  21.000
# Assist                        268.0    0.173507   0.124851   0.00   0.100
# Non_penalty_goals             268.0    0.197388   0.140733   0.00   0.100
# Non_penalty_xG                268.0    0.191418   0.100005   0.00   0.100
# Expected_assisted_goals       268.0    0.164925   0.091805   0.00   0.100
# Expected_assists              268.0    0.148134   0.078111   0.00   0.100
# Goals-Expected_goals          268.0    0.002985   0.098635  -0.30  -0.100
# Assists-expGoals_assisted     268.0    0.005970   0.096966  -0.30  -0.100
# Non_penalty_expGoals_perShot  268.0    0.071903   0.068645  -0.20   0.050
# Shot_/90                      268.0    1.559030   1.051456   0.02   0.180
# Goals_perShot_onTarget        267.0    0.220225   0.164237   0.00   0.110
# Shots_onTarget                267.0    0.611648   0.352005   0.00   0.375
# Shots_onTarget%               268.0   26.135821  17.128146   0.00   1.375
# Passes_completed              268.0   30.744776  10.619712   0.00  22.975
# Passes_attempted              268.0   36.178731  11.870984  11.50  28.100
# Passes_completition%          268.0   64.579104  17.973147  15.30  57.050
# Passes_into18yard_box         268.0    1.375746   0.935429   0.20   0.800
# Crosses_into18yard_box        268.0    0.448134   0.505287   0.00   0.100
# Progressive_passes            268.0    3.095149   2.313099   0.00   0.775
# Attempted_long_passes         268.0    3.998134   2.634451   0.10   2.100
# Carries/90                    268.0   36.491791  11.109233  16.80  28.075
# PrgDist_Carries               268.0  133.209328  66.150415  37.50  83.750
# Carries_10yards_forward       268.0   30.365672  49.070261   1.10   2.700
# Carries_into_final_third      268.0    2.736567   1.116545   0.80   2.000
# Carries_into18yard_box        268.0    1.375373   0.968758   0.10   0.700
# Miscontrols                   268.0    2.276493   0.971855   0.20   1.700
# Dispossesd                    268.0    2.113806   0.807453   0.60   1.500
# Goal_creating_actions         268.0    2.404478   3.596594   0.00   0.300
# PassLive_lead_goal            268.0    0.278731   0.192059   0.00   0.200
# Shot_creating_actions         268.0    2.650746   1.702730   0.00   0.600
# PassLive_lead_shot_attempt    268.0    2.479851   0.973721   0.70   1.800
# Aerials_Won%                  268.0   35.301493  11.953602   0.00  27.650
# Fouls_committed               268.0    1.266045   0.521884   0.20   0.900
# Fouls_drawn                   268.0    1.732463   0.830567   0.20   1.100
# Tackles_on_dribblers          268.0    0.572761   0.322973   0.00   0.400
# Lost_challange_drib_player    268.0    1.177239   0.507292   0.20   0.800
# Blocking_ball                 268.0    0.884328   0.357552   0.10   0.600
# Interceptions                 268.0    0.706716   0.380360   0.10   0.400
# Tackles_+Interc               268.0    2.267537   0.913297   0.50   1.600
# Clearences                    268.0    0.499627   0.348512   0.00   0.275
# Dead_ball_pass                268.0    3.006343   2.291181   0.10   1.100
# Passes_freeKick               268.0    0.824254   0.789046   0.00   0.200
# Passes_behind_defenders       268.0    0.221269   0.309456   0.00   0.100
# Swing_passes                  268.0    0.319030   0.299519   0.00   0.100
# Crosses                       268.0    3.242910   1.997580   0.20   1.700
# Corner_kikcs                  268.0    1.289552   1.375836   0.00   0.100
# Offsides                      268.0    0.237687   0.206716   0.00   0.100
# Succ_Takes_on%                268.0   55.171269   9.983696  20.00  47.775
# Touches_Def_Pen               268.0    0.657836   0.470371   0.00   0.300
# Touches_Def_3rd               268.0    6.014925   2.472455   1.80   4.400
# Touches_Mid_3rd               268.0   23.976866   7.949621   7.80  18.675
# Touches_Att_3rd               268.0   22.091045   5.034517  10.40  19.000
# Touches_Att_Pen               268.0    3.140672   1.172990   0.40   2.300
# has_sot                       268.0    0.966418   0.180488   0.00   1.000
# has_goal                      268.0    0.876866   0.329206   0.00   1.000
# has_assist                    268.0    0.880597   0.324869   0.00   1.000
#
#                                  50%      75%    max
# Age                            23.00   25.000   28.0
# Assist                          0.20    0.200    0.8
# Non_penalty_goals               0.20    0.300    0.8
# Non_penalty_xG                  0.20    0.200    0.7
# Expected_assisted_goals         0.10    0.200    0.6
# Expected_assists                0.10    0.200    0.5
# Goals-Expected_goals            0.00    0.100    0.3
# Assists-expGoals_assisted       0.00    0.100    0.4
# Non_penalty_expGoals_perShot    0.09    0.110    0.3
# Shot_/90                        1.70    2.200    4.5
# Goals_perShot_onTarget          0.20    0.310    1.0
# Shots_onTarget                  0.60    0.800    2.2
# Shots_onTarget%                31.35   39.000   66.7
# Passes_completed               28.85   36.925   72.7
# Passes_attempted               34.05   43.625   81.2
# Passes_completition%           71.40   77.300   91.1
# Passes_into18yard_box           1.15    1.525    6.7
# Crosses_into18yard_box          0.30    0.500    4.4
# Progressive_passes              2.95    4.500   11.1
# Attempted_long_passes           3.45    5.400   19.5
# Carries/90                     33.75   43.225   67.1
# PrgDist_Carries               114.55  171.625  525.4
# Carries_10yards_forward         3.60   55.875  259.9
# Carries_into_final_third        2.60    3.400    7.7
# Carries_into18yard_box          1.10    1.900    7.1
# Miscontrols                     2.30    2.900    5.3
# Dispossesd                      2.00    2.600    4.8
# Goal_creating_actions           0.50    4.150   14.3
# PassLive_lead_goal              0.20    0.400    1.7
# Shot_creating_actions           2.95    3.725    8.8
# PassLive_lead_shot_attempt      2.30    2.900    8.9
# Aerials_Won%                   34.85   42.100   75.0
# Fouls_committed                 1.20    1.600    3.1
# Fouls_drawn                     1.60    2.200    5.2
# Tackles_on_dribblers            0.50    0.700    2.5
# Lost_challange_drib_player      1.10    1.500    3.1
# Blocking_ball                   0.85    1.100    2.3
# Interceptions                   0.70    0.900    2.1
# Tackles_+Interc                 2.10    2.725    5.6
# Clearences                      0.40    0.600    1.9
# Dead_ball_pass                  2.35    4.600   10.3
# Passes_freeKick                 0.60    1.300    4.7
# Passes_behind_defenders         0.10    0.300    2.9
# Swing_passes                    0.20    0.400    1.6
# Crosses                         2.90    4.325   11.0
# Corner_kikcs                    0.70    2.200    6.4
# Offsides                        0.20    0.300    1.0
# Succ_Takes_on%                 55.60   62.500   80.0
# Touches_Def_Pen                 0.60    0.800    2.9
# Touches_Def_3rd                 5.60    7.025   21.8
# Touches_Mid_3rd                22.15   27.250   58.5
# Touches_Att_3rd                21.45   24.700   45.9
# Touches_Att_Pen                 3.10    3.900    7.2
# has_sot                         1.00    1.000    1.0
# has_goal                        1.00    1.000    1.0
# has_assist                      1.00    1.000    1.0

# %%
def_mid[FEATURES_DEF].describe().T
# Out:
#                               count        mean         std    min      25%  \
# Age                           322.0   23.372671    2.690285  18.00   21.000
# Assist                        322.0    0.077640    0.093045   0.00    0.000
# G+A                           322.0    0.143478    0.130316   0.00    0.000
# Non_penalty_goals             322.0    0.056832    0.075090   0.00    0.000
# Non_penalty_xG                322.0    0.066770    0.062513   0.00    0.000
# Expected_assisted_goals       322.0    0.073913    0.070620   0.00    0.000
# Expected_assists              322.0    0.066460    0.065514   0.00    0.000
# Non_penalty_expGoals_perShot  322.0    0.066087    0.045229  -0.20    0.040
# Shot_/90                      322.0    0.975435    0.548067   0.03    0.600
# Goals_per_shot                322.0    0.094752    0.228213   0.00    0.000
# Goals_perShot_onTarget        295.0    0.194508    0.218917   0.00    0.000
# Shots_onTarget                322.0    0.263727    0.201563   0.00    0.100
# Shots_onTarget%               322.0   24.368012   13.959508   0.00   15.400
# Passes_attempted              322.0   50.402795   14.966006  16.60   41.300
# Passes_completition%          322.0   80.899068    9.058087  23.60   78.400
# Passes_toShot                 322.0    4.006832   15.397836   0.10    0.500
# Passes_into18yard_box         322.0    0.679193    0.725483   0.00    0.300
# Crosses_into18yard_box        322.0    0.132919    0.233162   0.00    0.000
# Progressive_passes            322.0    4.961491    2.062801   0.00    3.800
# TotDist_completed_passes      322.0  692.316460  280.730483   2.50  536.475
# TotProgressive_passes         322.0  222.960559  126.008171  61.70  157.525
# Attempted_long_passes         322.0    6.280435    2.582813   1.20    4.500
# Long_passes_Cmp%              322.0   63.008075   15.664671   2.10   57.525
# Carries/90                    322.0   36.843168   12.010008  13.40   28.800
# TotDist_Carries               322.0  181.942857   65.940314  20.90  143.450
# PrgDist_Carries               322.0   94.750311   41.000483  19.30   69.025
# Carries_10yards_forward       322.0    4.254969   16.257923   0.00    0.800
# Carries_into_final_third      322.0    1.345342    0.794212   0.10    0.800
# Carries_into18yard_box        322.0    0.250932    0.404125   0.00    0.025
# Miscontrols                   322.0    1.461491    0.679294   0.10    1.000
# Dispossesd                    322.0    1.074845    0.552384   0.00    0.700
# Goal_creating_actions         322.0    0.403416    1.248733   0.00    0.100
# PassLive_lead_goal            322.0    0.151863    0.127569   0.00    0.100
# Shot_creating_actions         322.0    2.118944    0.980137   0.00    1.400
# PassLive_lead_shot_attempt    322.0    1.671739    0.709466   0.30    1.200
# Aerials_Won%                  322.0   47.227640   13.291309   0.00   40.000
# Fouls_committed               322.0    1.549379    0.512294   0.30    1.200
# Fouls_drawn                   322.0    1.300311    0.619290   0.10    0.900
# Tackles_won                   322.0    1.363975    0.493263   0.10    1.000
# Tackles_on_dribblers          322.0    0.898447    0.385764   0.10    0.600
# Lost_challange_drib_player    322.0    1.464596    0.577664   0.30    1.100
# Blocking_ball                 322.0    1.137267    0.384646   0.20    0.900
# Blocking_shots                322.0    0.241615    0.181052   0.00    0.100
# Blocking_pass                 322.0    0.894410    0.337528   0.20    0.625
# Interceptions                 322.0    1.318323    0.530743   0.10    0.900
# Tackles_+Interc               322.0    3.603416    1.048491   1.20    2.800
# Clearences                    322.0    1.202484    0.735097   0.10    0.700
# Dead_ball_pass                322.0    2.074534    1.774333   0.10    0.900
# Passes_freeKick               322.0    1.117081    0.785967   0.00    0.500
# Passes_behind_defenders       322.0    0.148758    0.173695   0.00    0.000
# Swing_passes                  322.0    0.580745    0.462960   0.00    0.300
# Crosses                       322.0    1.261180    1.429795   0.00    0.300
# Corner_kikcs                  322.0    0.458696    0.881094   0.00    0.000
# Succ_Takes_on%                322.0   64.259006   14.074056   0.00   55.850
# Touches_Def_Pen               322.0    1.946584    1.144758   0.00    1.100
# Touches_Def_3rd               322.0   12.732298    4.746674   3.30    9.400
# Touches_Att_3rd               322.0   11.624224    5.504207   1.60    7.900
# Touches_Att_Pen               322.0    1.048447    0.720125   0.00    0.500
# has_goal                      322.0    0.447205    0.497979   0.00    0.000
# has_assist                    322.0    0.546584    0.498600   0.00    0.000
#
#                                  50%      75%     max
# Age                            23.00   25.750    28.0
# Assist                          0.10    0.100     0.7
# G+A                             0.10    0.200     0.7
# Non_penalty_goals               0.00    0.100     0.4
# Non_penalty_xG                  0.10    0.100     0.3
# Expected_assisted_goals         0.10    0.100     0.3
# Expected_assists                0.10    0.100     0.3
# Non_penalty_expGoals_perShot    0.06    0.080     0.4
# Shot_/90                        0.90    1.300     2.7
# Goals_per_shot                  0.04    0.090     1.7
# Goals_perShot_onTarget          0.15    0.300     1.0
# Shots_onTarget                  0.20    0.400     1.1
# Shots_onTarget%                25.00   33.300    66.7
# Passes_attempted               48.00   56.075   108.6
# Passes_completition%           82.70   85.800    95.6
# Passes_toShot                   0.80    1.100    90.4
# Passes_into18yard_box           0.50    0.800     6.6
# Crosses_into18yard_box          0.10    0.200     2.0
# Progressive_passes              4.80    6.000    12.5
# TotDist_completed_passes      672.15  830.975  1636.0
# TotProgressive_passes         194.50  246.500  1134.5
# Attempted_long_passes           5.90    7.800    17.1
# Long_passes_Cmp%               65.95   73.075    94.1
# Carries/90                     34.90   41.075    82.5
# TotDist_Carries               174.35  213.650   453.8
# PrgDist_Carries                86.15  108.400   268.4
# Carries_10yards_forward         1.40    2.100   121.1
# Carries_into_final_third        1.10    1.800     3.9
# Carries_into18yard_box          0.10    0.300     2.6
# Miscontrols                     1.40    1.800     3.7
# Dispossesd                      1.00    1.400     3.2
# Goal_creating_actions           0.20    0.300    11.1
# PassLive_lead_goal              0.10    0.200     0.8
# Shot_creating_actions           2.00    2.600     5.0
# PassLive_lead_shot_attempt      1.60    2.000     4.6
# Aerials_Won%                   48.45   55.775   100.0
# Fouls_committed                 1.50    1.900     3.5
# Fouls_drawn                     1.20    1.700     3.9
# Tackles_won                     1.30    1.700     3.0
# Tackles_on_dribblers            0.90    1.200     2.2
# Lost_challange_drib_player      1.40    1.800     3.6
# Blocking_ball                   1.10    1.400     2.9
# Blocking_shots                  0.20    0.300     1.2
# Blocking_pass                   0.90    1.100     2.3
# Interceptions                   1.30    1.600     3.2
# Tackles_+Interc                 3.60    4.300     6.1
# Clearences                      1.10    1.600     4.0
# Dead_ball_pass                  1.40    2.700     9.1
# Passes_freeKick                 1.00    1.500     3.7
# Passes_behind_defenders         0.10    0.200     1.5
# Swing_passes                    0.50    0.700     4.8
# Crosses                         0.70    1.800     8.1
# Corner_kikcs                    0.00    0.400     4.7
# Succ_Takes_on%                 63.90   74.200   100.0
# Touches_Def_Pen                 1.80    2.475     8.4
# Touches_Def_3rd                12.10   14.900    32.0
# Touches_Att_3rd                10.70   14.875    28.2
# Touches_Att_Pen                 0.90    1.400     3.5
# has_goal                        0.00    1.000     1.0
# has_assist                      1.00    1.000     1.0

# %%
# Exploring the nature of zeros presents in the datasets

zero_frac_off = (off_mid[FEATURES_OFF] == 0).mean().sort_values(ascending=False)
zero_frac_def = (def_mid[FEATURES_DEF] == 0).mean().sort_values(ascending=False)

zero_frac_off.head(15), zero_frac_def.head(15)
# Out:
# (Assists-expGoals_assisted       0.455224
#  Goals-Expected_goals            0.432836
#  Passes_behind_defenders         0.212687
#  Corner_kikcs                    0.190299
#  Offsides                        0.167910
#  Non_penalty_goals               0.130597
#  has_goal                        0.123134
#  Assist                          0.119403
#  has_assist                      0.119403
#  Swing_passes                    0.119403
#  Goals_perShot_onTarget          0.115672
#  Passes_freeKick                 0.111940
#  Non_penalty_expGoals_perShot    0.104478
#  Crosses_into18yard_box          0.097015
#  Expected_assists                0.052239
#  dtype: float64,
#  Non_penalty_goals          0.568323
#  Corner_kikcs               0.568323
#  has_goal                   0.552795
#  Assist                     0.453416
#  has_assist                 0.453416
#  Expected_assists           0.431677
#  Goals_per_shot             0.419255
#  Non_penalty_xG             0.413043
#  Crosses_into18yard_box     0.409938
#  Expected_assisted_goals    0.397516
#  Goals_perShot_onTarget     0.350932
#  Passes_behind_defenders    0.295031
#  G+A                        0.263975
#  Carries_into18yard_box     0.251553
#  PassLive_lead_goal         0.198758
#  dtype: float64)

# %%
off_mid[FEATURES_OFF].isna().mean().sort_values(ascending=False).head(10)
# Out:
# Goals_perShot_onTarget       0.003731
# Shots_onTarget               0.003731
# Age                          0.000000
# Assist                       0.000000
# Expected_assisted_goals      0.000000
# Expected_assists             0.000000
# Non_penalty_goals            0.000000
# Non_penalty_xG               0.000000
# Assists-expGoals_assisted    0.000000
# Goals-Expected_goals         0.000000
# dtype: float64

# %%
def_mid[FEATURES_DEF].isna().mean().sort_values(ascending=False).head(10)
# Out:
# Goals_perShot_onTarget          0.083851
# Age                             0.000000
# G+A                             0.000000
# Assist                          0.000000
# Non_penalty_goals               0.000000
# Non_penalty_xG                  0.000000
# Expected_assists                0.000000
# Expected_assisted_goals         0.000000
# Non_penalty_expGoals_perShot    0.000000
# Shot_/90                        0.000000
# dtype: float64

# %%
# Target Distribution

off_mid[TARGET].value_counts(normalize=True)
# Out:
# Tier_league
# 0    0.757463
# 1    0.242537
# Name: proportion, dtype: float64

# %%
def_mid[TARGET].value_counts(normalize=True)
# Out:
# Tier_league
# 0    0.763975
# 1    0.236025
# Name: proportion, dtype: float64

# %%
# More pruning

DROP_OFF = [
    "has_sot",
    "has_goal",
    "has_assist",
    "Assists-expGoals_assisted",      
    "Goals-Expected_goals", 
]
DROP_DEF = [
    "has_goal",
    "has_assist",
    " Non_penalty_goals",
    "Corner_kikcs",
]

# %%
off_mid = off_mid.drop(columns=[c for c in DROP_OFF if c in off_mid.columns])
def_mid = def_mid.drop(columns=[c for c in DROP_DEF if c in def_mid.columns])

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET = "Tier_league"

FEATURES_OFF = [c for c in off_mid.columns if c not in ID_COLS + [TARGET]]
FEATURES_DEF = [c for c in def_mid.columns if c not in ID_COLS + [TARGET]]

print("OFF features:", len(FEATURES_OFF))
print("DEF features:", len(FEATURES_DEF))
# Out:
# OFF features: 51
# DEF features: 57

# %%
# Last check of high correlation

def get_high_corr_pairs_features(df, features, threshold=0.8):
    corr = df[features].corr().abs()

    upper = corr.where(
        np.triu(np.ones(corr.shape), k=1).astype(bool)
    )

    pairs = (
        upper.stack()
        .reset_index()
        .rename(columns={
            "level_0": "f1",
            "level_1": "f2",
            0: "corr"
        })
        .sort_values("corr", ascending=False)
    )

    return pairs[pairs["corr"] >= threshold]

# %%
high_corr_off_08 = get_high_corr_pairs_features(
    off_mid,
    FEATURES_OFF,
    threshold=0.8
)

high_corr_def_08 = get_high_corr_pairs_features(
    def_mid,
    FEATURES_DEF,
    threshold=0.8
)

high_corr_off_08.head(20), high_corr_def_08.head(20)
# Out:
# (                           f1                        f2      corr
#  814   Carries_10yards_forward     Goal_creating_actions  0.926076
#  1201           Dead_ball_pass              Corner_kikcs  0.872771
#  569          Passes_attempted           Touches_Mid_3rd  0.869338
#  780           PrgDist_Carries  Carries_into_final_third  0.865676
#  779           PrgDist_Carries   Carries_10yards_forward  0.860519
#  781           PrgDist_Carries    Carries_into18yard_box  0.850556
#  1197           Dead_ball_pass           Passes_freeKick  0.844568
#  1212          Passes_freeKick              Corner_kikcs  0.844382
#  1239                  Crosses              Corner_kikcs  0.840453
#  583      Passes_completition%     Goal_creating_actions  0.834290
#  811   Carries_10yards_forward    Carries_into18yard_box  0.833336
#  469           Shots_onTarget%     Goal_creating_actions  0.827639
#  649    Crosses_into18yard_box   Carries_10yards_forward  0.824683
#  194   Expected_assisted_goals          Expected_assists  0.821279
#  464           Shots_onTarget%   Carries_10yards_forward  0.820568
#  537          Passes_attempted        Progressive_passes  0.819592
#  690        Progressive_passes     Shot_creating_actions  0.819147
#  330                  Shot_/90            Shots_onTarget  0.813849
#  1192               Clearences           Touches_Def_Pen  0.803892
#  457           Shots_onTarget%      Passes_completition%  0.800870,
#                              f1                        f2      corr
#  1135   Carries_10yards_forward     Goal_creating_actions  0.914178
#  473             Goals_per_shot             Passes_toShot  0.883670
#  655           Passes_attempted  TotDist_completed_passes  0.882274
#  1477             Blocking_ball             Blocking_pass  0.877194
#  700       Passes_completition%          Long_passes_Cmp%  0.877058
#  1036                Carries/90           PrgDist_Carries  0.841523
#  1547                Clearences           Touches_Def_Pen  0.824816
#  484             Goals_per_shot   Carries_10yards_forward  0.821728
#  1590           Touches_Def_Pen           Touches_Def_3rd  0.809085
#  1431               Tackles_won           Tackles_+Interc  0.803838
#  1188  Carries_into_final_third           Touches_Att_3rd  0.800323)

# %%
DROP_OFF_08 = [
    "Carries_10yards_forward",
    "Carries_into_final_third",
    "Carries_into18yard_box",
    "Corner_kicks",
    "Passes_freeKick",
    "Passes_attempted",
    "Shots_onTarget",
    "Expected_assisted_goals",
    "Clearences",
]

# %%
DROP_DEF_08 = [
    "Blocking_pass",
    "Passes_attempted",
    "Goals_per_shot",
    "Passes_completition%",
    "Carries/90",
    "Touches_Def_Pen",
    "Clearences",
    "Tackles_won",
    "Touches_Att_3rd",
]

# %%
off_mid = off_mid.drop(columns=[c for c in DROP_OFF_08 if c in off_mid.columns])
def_mid = def_mid.drop(columns=[c for c in DROP_DEF_08 if c in def_mid.columns])

FEATURES_OFF = [c for c in off_mid.columns if c not in ID_COLS + [TARGET]]
FEATURES_DEF = [c for c in def_mid.columns if c not in ID_COLS + [TARGET]]

print("OFF features:", len(FEATURES_OFF))
print("DEF features:", len(FEATURES_DEF))
# Out:
# OFF features: 43
# DEF features: 48

# %%
high_corr_off_08b = get_high_corr_pairs_features(off_mid, FEATURES_OFF, threshold=0.8)
high_corr_def_08b = get_high_corr_pairs_features(def_mid, FEATURES_DEF, threshold=0.8)

print("OFF remaining pairs:", len(high_corr_off_08b))
print("DEF remaining pairs:", len(high_corr_def_08b))

high_corr_off_08b.head(20), high_corr_def_08b.head(20)
# Out:
# OFF remaining pairs: 6
# DEF remaining pairs: 1
# (                       f1                     f2      corr
#  840        Dead_ball_pass           Corner_kikcs  0.872771
#  867               Crosses           Corner_kikcs  0.840453
#  383  Passes_completition%  Goal_creating_actions  0.834290
#  318       Shots_onTarget%  Goal_creating_actions  0.827639
#  475    Progressive_passes  Shot_creating_actions  0.819147
#  309       Shots_onTarget%   Passes_completition%  0.800870,
#                            f1                     f2      corr
#  807  Carries_10yards_forward  Goal_creating_actions  0.914178)

# %%
off_mid_final = off_mid.copy()
def_mid_final = def_mid.copy()

# %%
off_mid_final.to_csv(
    "off_mid_final.csv",
    index=False
)
def_mid_final.to_csv(
    "def_mid_final.csv",
    index=False
)

# %% [markdown]
# ### Baseline Models ###

# %%
# Custom Functions

def hit_at_k(y_true, y_score, k=20):
    
    y_true = np.asarray(y_true)
    y_score = np.asarray(y_score)

    k = min(k, len(y_true))
    idx = np.argsort(-y_score)[:k]
    hits = y_true[idx].sum()
    total_pos = y_true.sum()
    if total_pos == 0:
        return np.nan
    return hits / total_pos


def ndcg_at_k(y_true, y_score, k=20):
    
    y_true = np.asarray(y_true)
    y_score = np.asarray(y_score)

    k = min(k, len(y_true))
    order = np.argsort(-y_score)[:k]
    rel = y_true[order]

    
    gains = (2**rel - 1)
    discounts = np.log2(np.arange(2, k + 2))
    dcg = np.sum(gains / discounts)

    ideal_rel = np.sort(y_true)[::-1][:k]
    ideal_gains = (2**ideal_rel - 1)
    idcg = np.sum(ideal_gains / discounts)

    if idcg == 0:
        return np.nan
    return dcg / idcg



def evaluate_binary_model(name, model, X_train, X_test, y_train, y_test, k=20):
    model.fit(X_train, y_train)

    proba = model.predict_proba(X_test)[:, 1]
    pred = (proba >= 0.5).astype(int)

    out = {
        "model": name,
        "accuracy": accuracy_score(y_test, pred),
        "precision": precision_score(y_test, pred, zero_division=0),
        "recall": recall_score(y_test, pred, zero_division=0),
        "f1": f1_score(y_test, pred, zero_division=0),
        "roc_auc": roc_auc_score(y_test, proba),
        "pr_auc": average_precision_score(y_test, proba),
        "hit@20": hit_at_k(y_test, proba, k=k),
        "ndcg@20": ndcg_at_k(y_test, proba, k=k),
        "cm": confusion_matrix(y_test, pred)
    }
    return out




def make_preprocessor(feature_cols):
    
    numeric_features = feature_cols
    numeric_transformer = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])
    preprocessor = ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, numeric_features)
        ],
        remainder="drop"
    )
    return preprocessor


def make_preprocessor_no_scale(feature_cols):
    numeric_features = feature_cols
    numeric_transformer = Pipeline(steps=[
        ("imputer", SimpleImputer(strategy="median"))
    ])
    preprocessor = ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, numeric_features)
        ],
        remainder="drop"
    )
    return preprocessor



def run_baselines(df, dataset_name, id_cols, target_col, test_size=0.25, random_state=42):
    df = df.copy()

    feature_cols = [c for c in df.columns if c not in id_cols + [target_col]]
    X = df[feature_cols]
    y = df[target_col].astype(int)

    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, stratify=y, random_state=random_state
    )

    # Logistic
    log_pre = make_preprocessor(feature_cols)
    log_model = Pipeline(steps=[
        ("pre", log_pre),
        ("clf", LogisticRegression(
            max_iter=2000,
            class_weight="balanced",
            solver="lbfgs"
        ))
    ])

    # MLP 
    mlp_pre = make_preprocessor(feature_cols)
    mlp_model = Pipeline(steps=[
        ("pre", mlp_pre),
        ("clf", MLPClassifier(
            hidden_layer_sizes=(64, 32),
            activation="relu",
            alpha=1e-4,
            learning_rate_init=1e-3,
            max_iter=800,
            early_stopping=True,
            random_state=random_state
        ))
    ])

    # XGBoost 
    xgb_pre = make_preprocessor_no_scale(feature_cols)
    xgb_model = Pipeline(steps=[
        ("pre", xgb_pre),
        ("clf", XGBClassifier(
            n_estimators=400,
            max_depth=4,
            learning_rate=0.05,
            subsample=0.9,
            colsample_bytree=0.9,
            reg_lambda=1.0,
            min_child_weight=1,
            objective="binary:logistic",
            eval_metric="logloss",
            random_state=random_state,
            n_jobs=-1
        ))
    ])

    results = []
    results.append(evaluate_binary_model(f"{dataset_name} | Logistic", log_model, X_train, X_test, y_train, y_test))
    results.append(evaluate_binary_model(f"{dataset_name} | XGBoost", xgb_model, X_train, X_test, y_train, y_test))
    results.append(evaluate_binary_model(f"{dataset_name} | MLP", mlp_model, X_train, X_test, y_train, y_test))

    res_df = pd.DataFrame([{k: v for k, v in r.items() if k != "cm"} for r in results])
    cms = {r["model"]: r["cm"] for r in results}

    return res_df.sort_values("ndcg@20", ascending=False), cms



ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET = "Tier_league"

off_results, off_cms = run_baselines(off_mid, "OFF_MID", ID_COLS, TARGET)
def_results, def_cms = run_baselines(def_mid, "DEF_MID", ID_COLS, TARGET)

display(off_results)
display(def_results)

print("\nConfusion matrices (OFF MID):")
for k, v in off_cms.items():
    print(k, "\n", v, "\n")

print("\nConfusion matrices (DEF MID):")
for k, v in def_cms.items():
    print(k, "\n", v, "\n")
# Out:
#                 model  accuracy  precision  recall        f1   roc_auc  \
# 0  OFF_MID | Logistic  0.791045   0.555556  0.6250  0.588235  0.857843
# 1   OFF_MID | XGBoost  0.820896   0.700000  0.4375  0.538462  0.800245
# 2       OFF_MID | MLP  0.791045   0.600000  0.3750  0.461538  0.803922
#
#      pr_auc  hit@20   ndcg@20
# 0  0.694579  0.6875  0.735438
# 1  0.618946  0.6875  0.701050
# 2  0.557304  0.5000  0.568971
#                 model  accuracy  precision    recall        f1   roc_auc  \
# 0  DEF_MID | Logistic  0.790123   0.533333  0.842105  0.653061  0.877759
# 1   DEF_MID | XGBoost  0.827160   0.631579  0.631579  0.631579  0.870968
# 2       DEF_MID | MLP  0.740741   0.400000  0.210526  0.275862  0.679117
#
#      pr_auc    hit@20   ndcg@20
# 0  0.760024  0.684211  0.757456
# 1  0.680733  0.631579  0.693984
# 2  0.374866  0.368421  0.348877
# Confusion matrices (OFF MID):
# OFF_MID | Logistic
#  [[43  8]
#  [ 6 10]]
#
# OFF_MID | XGBoost
#  [[48  3]
#  [ 9  7]]
#
# OFF_MID | MLP
#  [[47  4]
#  [10  6]]
#
#
# Confusion matrices (DEF MID):
# DEF_MID | Logistic
#  [[48 14]
#  [ 3 16]]
#
# DEF_MID | XGBoost
#  [[55  7]
#  [ 7 12]]
#
# DEF_MID | MLP
#  [[56  6]
#  [15  4]]

# %% [markdown]
# ### Tuning Models ###

# %%
# Setup

SEED = 42
TEST_SIZE = 0.25
K = 20



FEATURES_OFF = [c for c in FEATURES_OFF if c in off_mid.columns]
FEATURES_DEF = [c for c in FEATURES_DEF if c in def_mid.columns]



X_off = off_mid[FEATURES_OFF].copy()
y_off = off_mid[TARGET].astype(int).copy()

X_def = def_mid[FEATURES_DEF].copy()
y_def = def_mid[TARGET].astype(int).copy()

X_train_off, X_test_off, y_train_off, y_test_off = train_test_split(
    X_off, y_off, test_size=TEST_SIZE, random_state=SEED, stratify=y_off
)

X_train_def, X_test_def, y_train_def, y_test_def = train_test_split(
    X_def, y_def, test_size=TEST_SIZE, random_state=SEED, stratify=y_def
)

print("OFF_MID shapes:", X_train_off.shape, X_test_off.shape, y_train_off.mean(), y_test_off.mean())
print("DEF_MID shapes:", X_train_def.shape, X_test_def.shape, y_train_def.mean(), y_test_def.mean())



def hit_at_k(y_true, y_score, k=20):
    y_true = np.asarray(y_true).astype(int)
    y_score = np.asarray(y_score)

    n = len(y_true)
    if n == 0:
        return 0.0

    k_eff = min(k, n)
    pos_total = int(y_true.sum())
    if pos_total == 0:
        return 0.0

    top_idx = np.argsort(-y_score)[:k_eff]
    return float(y_true[top_idx].sum() / pos_total)


def ndcg_at_k(y_true, y_score, k=20):
    y_true = np.asarray(y_true).astype(int)
    y_score = np.asarray(y_score)

    n = len(y_true)
    if n == 0:
        return 0.0

    k_eff = min(k, n)
    pos_total = int(y_true.sum())
    if pos_total == 0:
        return 0.0

    order = np.argsort(-y_score)
    y_sorted = y_true[order][:k_eff]

    gains = (2**y_sorted - 1)
    discounts = np.log2(np.arange(2, k_eff + 2))
    dcg = np.sum(gains / discounts)

    ideal_sorted = np.sort(y_true)[::-1][:k_eff]
    ideal_gains = (2**ideal_sorted - 1)
    idcg = np.sum(ideal_gains / discounts)

    if idcg == 0:
        return 0.0

    return float(dcg / idcg)



def make_logistic_pipe():
    return Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", LogisticRegression(
            solver="liblinear",
            l1_ratio=0.0,
            max_iter=5000,
            random_state=SEED
        ))
    ])

def make_mlp_pipe():
    return Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", MLPClassifier(
            max_iter=3000,
            early_stopping=True,
            n_iter_no_change=25,
            random_state=SEED
        ))
    ])

def make_xgb_pipe():
    return Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("clf", XGBClassifier(
            objective="binary:logistic",
            eval_metric="logloss",
            tree_method="hist",
            random_state=SEED
        ))
    ])

#Grid search space

LOG_GRID = {
    "clf__l1_ratio": [0.0, 1.0],   # 0 = L2, 1 = L1
    "clf__C": [0.01, 0.1, 1.0, 3.0, 10.0],
}

MLP_GRID = {
    "clf__hidden_layer_sizes": [(32,), (64,), (64, 32), (128,)],
    "clf__activation": ["relu", "tanh"],
    "clf__alpha": [1e-5, 1e-4, 1e-3],
    "clf__learning_rate_init": [1e-4, 5e-4, 1e-3],
}

XGB_GRID = {
    "clf__n_estimators": [200, 400],
    "clf__max_depth": [2, 3, 4],
    "clf__learning_rate": [0.03, 0.05, 0.1],
    "clf__subsample": [0.8, 1.0],
    "clf__colsample_bytree": [0.7, 0.9, 1.0],
    "clf__min_child_weight": [1, 5],
}



def tune_with_ndcg20(name, pipe, grid, X_train, y_train, k=20):
    cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=SEED)

    def ndcg20_cv_scorer(estimator, X, y):
        proba = estimator.predict_proba(X)[:, 1]
        return ndcg_at_k(y, proba, k=k)

    gs = GridSearchCV(
        estimator=pipe,
        param_grid=grid,
        scoring=ndcg20_cv_scorer,
        cv=cv,
        n_jobs=-1,
        verbose=1,
        error_score="raise"
    )

    print(f"\n===== {name}: Tuning (optimise NDCG@{k}) =====")
    gs.fit(X_train, y_train)
    print("Best params:", gs.best_params_)
    print(f"Best CV ndcg@{k}: {gs.best_score_:.6f}")
    return gs.best_estimator_, gs.best_params_, gs.best_score_


def eval_binary_and_ranking(model, X_test, y_test, k=20):
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]

    out = {
        "accuracy": accuracy_score(y_test, y_pred),
        "precision": precision_score(y_test, y_pred, zero_division=0),
        "recall": recall_score(y_test, y_pred, zero_division=0),
        "f1": f1_score(y_test, y_pred, zero_division=0),
        "roc_auc": roc_auc_score(y_test, y_proba),
        "pr_auc": average_precision_score(y_test, y_proba),
        f"hit@{k}": hit_at_k(y_test, y_proba, k=k),
        f"ndcg@{k}": ndcg_at_k(y_test, y_proba, k=k),
        "confusion_matrix": confusion_matrix(y_test, y_pred)
    }
    return out


def run_all_3_models(group_name, X_train, y_train, X_test, y_test, k=20):
    rows = []
    cms = {}
    tuned = {}

    # Logistic
    best_log, bp_log, cv_log = tune_with_ndcg20(
        f"{group_name} Logistic", make_logistic_pipe(), LOG_GRID, X_train, y_train, k=k
    )
    m_log = eval_binary_and_ranking(best_log, X_test, y_test, k=k)
    cms[f"{group_name} | Logistic (tuned)"] = m_log["confusion_matrix"]
    rows.append({"model": f"{group_name} | Logistic (tuned)", **{kk: vv for kk, vv in m_log.items() if kk != "confusion_matrix"}})
    tuned["logistic"] = {"best_params": bp_log, f"cv_ndcg@{k}": cv_log, "estimator": best_log}

    # XGBoost
    best_xgb, bp_xgb, cv_xgb = tune_with_ndcg20(
        f"{group_name} XGBoost", make_xgb_pipe(), XGB_GRID, X_train, y_train, k=k
    )
    m_xgb = eval_binary_and_ranking(best_xgb, X_test, y_test, k=k)
    cms[f"{group_name} | XGBoost (tuned)"] = m_xgb["confusion_matrix"]
    rows.append({"model": f"{group_name} | XGBoost (tuned)", **{kk: vv for kk, vv in m_xgb.items() if kk != "confusion_matrix"}})
    tuned["xgboost"] = {"best_params": bp_xgb, f"cv_ndcg@{k}": cv_xgb, "estimator": best_xgb}

    # MLP
    best_mlp, bp_mlp, cv_mlp = tune_with_ndcg20(
        f"{group_name} MLP", make_mlp_pipe(), MLP_GRID, X_train, y_train, k=k
    )
    m_mlp = eval_binary_and_ranking(best_mlp, X_test, y_test, k=k)
    cms[f"{group_name} | MLP (tuned)"] = m_mlp["confusion_matrix"]
    rows.append({"model": f"{group_name} | MLP (tuned)", **{kk: vv for kk, vv in m_mlp.items() if kk != "confusion_matrix"}})
    tuned["mlp"] = {"best_params": bp_mlp, f"cv_ndcg@{k}": cv_mlp, "estimator": best_mlp}

    df = pd.DataFrame(rows)
    metric_cols = ["accuracy", "precision", "recall", "f1", "roc_auc", "pr_auc", f"hit@{k}", f"ndcg@{k}"]
    df = df[["model"] + metric_cols]

    return df, cms, tuned



results_off, cms_off, tuned_off = run_all_3_models(
    "OFF_MID", X_train_off, y_train_off, X_test_off, y_test_off, k=K
)
print("\nOFF_MID tuned results:")
display(results_off)

results_def, cms_def, tuned_def = run_all_3_models(
    "DEF_MID", X_train_def, y_train_def, X_test_def, y_test_def, k=K
)
print("\nDEF_MID tuned results:")
display(results_def)

print("\nConfusion matrices (OFF_MID):")
for name, cm in cms_off.items():
    print(name)
    print(cm, "\n")

print("\nConfusion matrices (DEF_MID):")
for name, cm in cms_def.items():
    print(name)
    print(cm, "\n")
# Out:
# OFF_MID shapes: (201, 43) (67, 43) 0.24378109452736318 0.23880597014925373
# DEF_MID shapes: (241, 48) (81, 48) 0.23651452282157676 0.2345679012345679
#
# ===== OFF_MID Logistic: Tuning (optimise NDCG@20) =====
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Best params: {'clf__C': 1.0, 'clf__l1_ratio': 1.0}
# Best CV ndcg@20: 0.793324
#
# ===== OFF_MID XGBoost: Tuning (optimise NDCG@20) =====
# Fitting 4 folds for each of 216 candidates, totalling 864 fits
# Best params: {'clf__colsample_bytree': 1.0, 'clf__learning_rate': 0.1, 'clf__max_depth': 2, 'clf__min_child_weight': 1, 'clf__n_estimators': 200, 'clf__subsample': 0.8}
# Best CV ndcg@20: 0.708276
#
# ===== OFF_MID MLP: Tuning (optimise NDCG@20) =====
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Best params: {'clf__activation': 'tanh', 'clf__alpha': 1e-05, 'clf__hidden_layer_sizes': (128,), 'clf__learning_rate_init': 0.001}
# Best CV ndcg@20: 0.758214
#
# OFF_MID tuned results:
#                         model  accuracy  precision  recall        f1  \
# 0  OFF_MID | Logistic (tuned)  0.835821   0.666667  0.6250  0.645161
# 1   OFF_MID | XGBoost (tuned)  0.850746   0.800000  0.5000  0.615385
# 2       OFF_MID | MLP (tuned)  0.746269   0.481481  0.8125  0.604651
#
#     roc_auc    pr_auc  hit@20   ndcg@20
# 0  0.872549  0.709805  0.7500  0.776034
# 1  0.817402  0.676430  0.6875  0.738699
# 2  0.849265  0.605308  0.6875  0.680411
# ===== DEF_MID Logistic: Tuning (optimise NDCG@20) =====
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# Best params: {'clf__C': 0.01, 'clf__l1_ratio': 0.0}
# Best CV ndcg@20: 0.738019
#
# ===== DEF_MID XGBoost: Tuning (optimise NDCG@20) =====
# Fitting 4 folds for each of 216 candidates, totalling 864 fits
# Best params: {'clf__colsample_bytree': 0.9, 'clf__learning_rate': 0.1, 'clf__max_depth': 3, 'clf__min_child_weight': 1, 'clf__n_estimators': 400, 'clf__subsample': 0.8}
# Best CV ndcg@20: 0.737052
#
# ===== DEF_MID MLP: Tuning (optimise NDCG@20) =====
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Best params: {'clf__activation': 'tanh', 'clf__alpha': 1e-05, 'clf__hidden_layer_sizes': (64, 32), 'clf__learning_rate_init': 0.001}
# Best CV ndcg@20: 0.716330
#
# DEF_MID tuned results:
#                         model  accuracy  precision    recall        f1  \
# 0  DEF_MID | Logistic (tuned)  0.814815   0.583333  0.736842  0.651163
# 1   DEF_MID | XGBoost (tuned)  0.851852   0.652174  0.789474  0.714286
# 2       DEF_MID | MLP (tuned)  0.888889   0.777778  0.736842  0.756757
#
#     roc_auc    pr_auc    hit@20   ndcg@20
# 0  0.909168  0.795947  0.736842  0.800712
# 1  0.883701  0.698403  0.631579  0.696529
# 2  0.889643  0.807189  0.789474  0.837859
# Confusion matrices (OFF_MID):
# OFF_MID | Logistic (tuned)
# [[46  5]
#  [ 6 10]]
#
# OFF_MID | XGBoost (tuned)
# [[49  2]
#  [ 8  8]]
#
# OFF_MID | MLP (tuned)
# [[37 14]
#  [ 3 13]]
#
#
# Confusion matrices (DEF_MID):
# DEF_MID | Logistic (tuned)
# [[52 10]
#  [ 5 14]]
#
# DEF_MID | XGBoost (tuned)
# [[54  8]
#  [ 4 15]]
#
# DEF_MID | MLP (tuned)
# [[58  4]
#  [ 5 14]]

# %% [markdown]
# ### Best Models

# %%
#Setup

TOP_N = 20   
RANDOM_STATE = 42


BEST_PARAMS = {
    "OFF_MID": {
        "Logistic": {"C": 1.0, "l1_ratio": 1.0},
        "XGBoost": {
            "colsample_bytree": 1.0,
            "learning_rate": 0.1,
            "max_depth": 2,
            "min_child_weight": 1,
            "n_estimators": 200,
            "subsample": 0.8,
        },
        "MLP": {
            "activation": "tanh",
            "alpha": 1e-5,
            "hidden_layer_sizes": (128,),
            "learning_rate_init": 0.001,
        },
    },
    "DEF_MID": {
        "Logistic": {"C": 0.01, "l1_ratio": 0.0},
        "XGBoost": {
            "colsample_bytree": 0.9,
            "learning_rate": 0.1,
            "max_depth": 3,
            "min_child_weight": 1,
            "n_estimators": 400,
            "subsample": 0.8,
        },
        "MLP": {
            "activation": "tanh",
            "alpha": 1e-5,
            "hidden_layer_sizes": (64, 32),
            "learning_rate_init": 0.001,
        },
    },
}


def build_logistic(best):

    l1_ratio = best["l1_ratio"]

    if l1_ratio == 1.0:
        solver = "liblinear"
    else:
        solver = "lbfgs"

    return LogisticRegression(
        C=best["C"],
        l1_ratio=l1_ratio,
        solver=solver,
        max_iter=5000,
        class_weight="balanced",
        random_state=RANDOM_STATE,
    )

def build_mlp(best):
    return MLPClassifier(
        hidden_layer_sizes=best["hidden_layer_sizes"],
        activation=best["activation"],
        alpha=best["alpha"],
        learning_rate_init=best["learning_rate_init"],
        max_iter=3000,
        early_stopping=True,
        n_iter_no_change=20,
        random_state=RANDOM_STATE,
    )

def build_xgb(best):
    return XGBClassifier(
        n_estimators=best["n_estimators"],
        max_depth=best["max_depth"],
        learning_rate=best["learning_rate"],
        subsample=best["subsample"],
        colsample_bytree=best["colsample_bytree"],
        min_child_weight=best["min_child_weight"],
        objective="binary:logistic",
        eval_metric="logloss",
        reg_lambda=1.0,
        random_state=RANDOM_STATE,
        n_jobs=-1,
    )

def make_pipeline(model_name, estimator):
    
    steps = [("imputer", SimpleImputer(strategy="median"))]

    if model_name in ["Logistic", "MLP"]:
        steps.append(("scaler", StandardScaler()))

    steps.append(("clf", estimator))
    return Pipeline(steps)


def make_scouting_table(df, features, id_cols, target, pipe, model_label, top_n=50):
    
    X = df[features].copy()
    y = df[target].astype(int).copy()

    pipe.fit(X, y)

    proba_1 = pipe.predict_proba(X)[:, 1]

    out = df[id_cols + [target]].copy()
    out["proba_1"] = proba_1
    out["pred"] = (out["proba_1"] >= 0.5).astype(int)

    out = out.sort_values("proba_1", ascending=False).reset_index(drop=True)
    out["rank"] = np.arange(1, len(out) + 1)

    
    cols_order = ["rank"] + id_cols + [target, "pred", "proba_1"]
    out = out[cols_order]

    top = out.head(top_n).copy()

    print(f"\n{model_label} | rows={len(out)} | positives={int(out[target].sum())} | pos_rate={out[target].mean():.3f}")
    print(top.head(10))

    return out, top, pipe


all_models = {}

ROLE_CONFIGS = {
    "OFF_MID": {"df": off_mid, "features": FEATURES_OFF},
    "DEF_MID": {"df": def_mid, "features": FEATURES_DEF},
}

for role_name in ["OFF_MID", "DEF_MID"]:
    df_role = ROLE_CONFIGS[role_name]["df"].copy()
    feats = ROLE_CONFIGS[role_name]["features"]

    role_models = {}

   
    log_est = build_logistic(BEST_PARAMS[role_name]["Logistic"])
    xgb_est = build_xgb(BEST_PARAMS[role_name]["XGBoost"])
    mlp_est = build_mlp(BEST_PARAMS[role_name]["MLP"])

    models = {
        "Logistic": make_pipeline("Logistic", log_est),
        "XGBoost": make_pipeline("XGBoost", xgb_est),
        "MLP": make_pipeline("MLP", mlp_est),
    }

    for model_name, pipe in models.items():
        label = f"{role_name} | {model_name} (locked, full-fit)"
        full_tbl, top_tbl, fitted_pipe = make_scouting_table(
            df=df_role,
            features=feats,
            id_cols=ID_COLS,
            target=TARGET,
            pipe=pipe,
            model_label=label,
            top_n=TOP_N,
        )

        # Save
        full_path = f"{role_name}_{model_name}_scouting_FULL.csv"
        top_path = f"{role_name}_{model_name}_scouting_TOP{TOP_N}.csv"
        full_tbl.to_csv(full_path, index=False)
        top_tbl.to_csv(top_path, index=False)

        role_models[model_name] = {
            "pipe": fitted_pipe,
            "full": full_tbl,
            "top": top_tbl,
            "full_path": full_path,
            "top_path": top_path,
        }

    all_models[role_name] = role_models

print("\nSaved scouting tables:")
for role_name in all_models:
    for model_name in all_models[role_name]:
        print(f"- {all_models[role_name][model_name]['full_path']}")
        print(f"- {all_models[role_name][model_name]['top_path']}")
# Out:
# OFF_MID | Logistic (locked, full-fit) | rows=268 | positives=65 | pos_rate=0.243
#    rank             Player     Season       Team Role  Tier_league  pred  \
# 0     1             Neymar  2017-2018  Paris S-G   LW            1     1
# 1     2             Neymar  2018-2019  Paris S-G   LW            1     1
# 2     3             Neymar  2019-2020  Paris S-G   LW            1     1
# 3     4     Javier Pastore  2017-2018  Paris S-G   AM            1     1
# 4     5     Julian Draxler  2017-2018  Paris S-G   LW            1     1
# 5     6    Florian Thauvin  2017-2018  Marseille   RW            1     1
# 6     7       Moussa Diaby  2018-2019  Paris S-G   RW            1     1
# 7     8  Aleksandr Golovin  2020-2021     Monaco   AM            1     1
# 8     9     Julian Draxler  2019-2020  Paris S-G   LW            1     1
# 9    10     Jonathan Ikone  2019-2020      Lille   RW            1     1
#
#     proba_1
# 0  1.000000
# 1  1.000000
# 2  0.999835
# 3  0.999793
# 4  0.999508
# 5  0.998767
# 6  0.998247
# 7  0.996414
# 8  0.993416
# 9  0.992935
#
# OFF_MID | XGBoost (locked, full-fit) | rows=268 | positives=65 | pos_rate=0.243
#    rank            Player     Season       Team Role  Tier_league  pred  \
# 0     1      Nicolas Pépé  2018-2019      Lille   RW            1     1
# 1     2            Neymar  2018-2019  Paris S-G   LW            1     1
# 2     3    Jonathan Ikone  2019-2020      Lille   RW            1     1
# 3     4            Neymar  2017-2018  Paris S-G   LW            1     1
# 4     5       Nabil Fekir  2018-2019       Lyon   AM            1     1
# 5     6    Julian Draxler  2017-2018  Paris S-G   LW            1     1
# 6     7   Florian Thauvin  2017-2018  Marseille   RW            1     1
# 7     8   Florian Thauvin  2018-2019  Marseille   RW            1     1
# 8     9  Giovani Lo Celso  2017-2018  Paris S-G   AM            1     1
# 9    10    Jonathan Ikone  2018-2019      Lille   RW            1     1
#
#     proba_1
# 0  0.993923
# 1  0.992537
# 2  0.988430
# 3  0.988103
# 4  0.987612
# 5  0.982837
# 6  0.982508
# 7  0.973875
# 8  0.970534
# 9  0.968421
#
# OFF_MID | MLP (locked, full-fit) | rows=268 | positives=65 | pos_rate=0.243
#    rank               Player     Season       Team Role  Tier_league  pred  \
# 0     1          David Costa  2021-2022       Lens   AM            0     1
# 1     2      Florian Thauvin  2017-2018  Marseille   RW            1     1
# 2     3               Malcom  2017-2018   Bordeaux   RW            0     1
# 3     4          Lovro Majer  2021-2022     Rennes   AM            1     1
# 4     5         Moussa Diaby  2018-2019  Paris S-G   RW            1     1
# 5     6               Neymar  2018-2019  Paris S-G   LW            1     1
# 6     7        Maxwel Cornet  2018-2019       Lyon   LW            1     1
# 7     8  Jeff Reine-Adélaïde  2019-2020    2 Teams   AM            0     1
# 8     9               Neymar  2019-2020  Paris S-G   LW            1     1
# 9    10       Julian Draxler  2020-2021  Paris S-G   LW            1     1
#
#     proba_1
# 0  0.874785
# 1  0.870397
# 2  0.834219
# 3  0.833093
# 4  0.832037
# 5  0.826220
# 6  0.811252
# 7  0.806494
# 8  0.801101
# 9  0.796729
#
# DEF_MID | Logistic (locked, full-fit) | rows=322 | positives=76 | pos_rate=0.236
#    rank           Player     Season       Team Role  Tier_league  pred  \
# 0     1    Adrien Rabiot  2018-2019  Paris S-G   RM            1     1
# 1     2   Marco Verratti  2017-2018  Paris S-G   CM            1     1
# 2     3   Marco Verratti  2018-2019  Paris S-G   CM            1     1
# 3     4    Adrien Rabiot  2017-2018  Paris S-G   RM            1     1
# 4     5   Marco Verratti  2019-2020  Paris S-G   CM            1     1
# 5     6  Tanguy Ndombele  2018-2019       Lyon   CM            1     1
# 6     7    Yves Bissouma  2017-2018      Lille   DM            1     1
# 7     8   Marco Verratti  2021-2022  Paris S-G   CM            1     1
# 8     9     Jordan Ferri  2017-2018       Lyon   CM            0     1
# 9    10   Marco Verratti  2020-2021  Paris S-G   CM            1     1
#
#     proba_1
# 0  0.985630
# 1  0.968963
# 2  0.938824
# 3  0.935253
# 4  0.931805
# 5  0.930413
# 6  0.919238
# 7  0.903522
# 8  0.898711
# 9  0.896141
#
# DEF_MID | XGBoost (locked, full-fit) | rows=322 | positives=76 | pos_rate=0.236
#    rank               Player     Season       Team Role  Tier_league  pred  \
# 0     1        Yves Bissouma  2017-2018      Lille   DM            1     1
# 1     2        Adrien Rabiot  2018-2019  Paris S-G   RM            1     1
# 2     3        Adrien Rabiot  2017-2018  Paris S-G   RM            1     1
# 3     4      Khéphren Thuram  2021-2022       Nice   CM            1     1
# 4     5              Fabinho  2017-2018     Monaco   CM            1     1
# 5     6  Aurélien Tchouaméni  2021-2022     Monaco   DM            1     1
# 6     7      Tanguy Ndombele  2018-2019       Lyon   CM            1     1
# 7     8      Leandro Paredes  2020-2021  Paris S-G   DM            1     1
# 8     9         Mario Lemina  2021-2022       Nice   DM            1     1
# 9    10      Ibrahim Sangaré  2018-2019   Toulouse   DM            1     1
#
#     proba_1
# 0  0.999650
# 1  0.998532
# 2  0.998202
# 3  0.998106
# 4  0.997452
# 5  0.997266
# 6  0.997112
# 7  0.995881
# 8  0.995780
# 9  0.994606
#
# DEF_MID | MLP (locked, full-fit) | rows=322 | positives=76 | pos_rate=0.236
#    rank               Player     Season       Team Role  Tier_league  pred  \
# 0     1        Adrien Rabiot  2018-2019  Paris S-G   RM            1     1
# 1     2        Yves Bissouma  2017-2018      Lille   DM            1     1
# 2     3        Adrien Rabiot  2017-2018  Paris S-G   RM            1     1
# 3     4       Marco Verratti  2017-2018  Paris S-G   CM            1     1
# 4     5      Leandro Paredes  2020-2021  Paris S-G   DM            1     1
# 5     6      Tanguy Ndombele  2018-2019       Lyon   CM            1     1
# 6     7      Khéphren Thuram  2021-2022       Nice   CM            1     1
# 7     8  Aurélien Tchouaméni  2021-2022     Monaco   DM            1     1
# 8     9       Marco Verratti  2019-2020  Paris S-G   CM            1     1
# 9    10       Marco Verratti  2018-2019  Paris S-G   CM            1     1
#
#     proba_1
# 0  0.982584
# 1  0.964569
# 2  0.963588
# 3  0.946266
# 4  0.944773
# 5  0.938561
# 6  0.918501
# 7  0.916978
# 8  0.916667
# 9  0.911947
#
# Saved scouting tables:
# - OFF_MID_Logistic_scouting_FULL.csv
# - OFF_MID_Logistic_scouting_TOP20.csv
# - OFF_MID_XGBoost_scouting_FULL.csv
# - OFF_MID_XGBoost_scouting_TOP20.csv
# - OFF_MID_MLP_scouting_FULL.csv
# - OFF_MID_MLP_scouting_TOP20.csv
# - DEF_MID_Logistic_scouting_FULL.csv
# - DEF_MID_Logistic_scouting_TOP20.csv
# - DEF_MID_XGBoost_scouting_FULL.csv
# - DEF_MID_XGBoost_scouting_TOP20.csv
# - DEF_MID_MLP_scouting_FULL.csv
# - DEF_MID_MLP_scouting_TOP20.csv

# %% [markdown]
# ### SHAP Feature Importance ###

# %%
def hit_rate_at_k(y_true, y_score, k=20):
  
    y_true = np.asarray(y_true)
    y_score = np.asarray(y_score)

    n_pos = int((y_true == 1).sum())
    if n_pos == 0:
        return np.nan

    k = min(k, len(y_true))
    top_idx = np.argsort(-y_score)[:k]
    hits = int((y_true[top_idx] == 1).sum())

    return hits / n_pos


def ndcg_at_k(y_true, y_score, k=20):
    
    y_true = np.asarray(y_true)
    y_score = np.asarray(y_score)

    k = min(k, len(y_true))
    order = np.argsort(-y_score)
    y_sorted = y_true[order][:k]

    gains = (2**y_sorted - 1).astype(float)  # binary relevance gives either 0 or 1
    discounts = 1.0 / np.log2(np.arange(2, k + 2))
    dcg = float((gains * discounts).sum())

    # Ideal DCG
    ideal_sorted = np.sort(y_true)[::-1][:k]
    ideal_gains = (2**ideal_sorted - 1).astype(float)
    idcg = float((ideal_gains * discounts).sum())

    if idcg == 0:
        return np.nan
    return dcg / idcg


def evaluate_binary_model(name, model, X_train, y_train, X_test, y_test, k=20):
  
    
    model.fit(X_train, y_train)
    proba = model.predict_proba(X_test)[:, 1]
    pred = (proba >= 0.5).astype(int)

    out = {
        "model": name,
        "accuracy": accuracy_score(y_test, pred),
        "precision": precision_score(y_test, pred, zero_division=0),
        "recall": recall_score(y_test, pred, zero_division=0),
        "f1": f1_score(y_test, pred, zero_division=0),
        "roc_auc": roc_auc_score(y_test, proba) if len(np.unique(y_test)) > 1 else np.nan,
        "pr_auc": average_precision_score(y_test, proba) if len(np.unique(y_test)) > 1 else np.nan,
        "hit@20": hit_rate_at_k(y_test, proba, k=k),
        "ndcg@20": ndcg_at_k(y_test, proba, k=k),
        "confusion_matrix": confusion_matrix(y_test, pred)
    }
    return out, model, proba


def make_train_test(df, features, target, test_size=0.25, random_state=42):
    X = df[features].copy()
    y = df[target].astype(int).copy()
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )
    return X_train, X_test, y_train, y_test



def build_logistic(best_params=None, random_state=42):
    
    if best_params is None:
        best_params = {"C": 1.0, "penalty": "l2"}

    clf = LogisticRegression(
        solver="liblinear",
        C=float(best_params.get("C", 1.0)),
        penalty=str(best_params.get("penalty", "l2")),
        class_weight="balanced",
        max_iter=5000,
        random_state=random_state
    )

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", clf)
    ])
    return pipe


def build_xgb(best_params=None, random_state=42):
    
    if best_params is None:
        best_params = {
            "n_estimators": 300,
            "max_depth": 3,
            "learning_rate": 0.1,
            "subsample": 0.8,
            "colsample_bytree": 0.9,
            "min_child_weight": 1
        }

    clf = XGBClassifier(
        n_estimators=int(best_params.get("n_estimators", 300)),
        max_depth=int(best_params.get("max_depth", 3)),
        learning_rate=float(best_params.get("learning_rate", 0.1)),
        subsample=float(best_params.get("subsample", 0.8)),
        colsample_bytree=float(best_params.get("colsample_bytree", 0.9)),
        min_child_weight=float(best_params.get("min_child_weight", 1)),
        reg_lambda=float(best_params.get("reg_lambda", 1.0)),
        reg_alpha=float(best_params.get("reg_alpha", 0.0)),
        objective="binary:logistic",
        eval_metric="logloss",
        n_jobs=-1,
        random_state=random_state
    )

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("clf", clf)
    ])
    return pipe


def build_mlp(best_params=None, random_state=42):
    
    if best_params is None:
        best_params = {
            "hidden_layer_sizes": (64, 32),
            "activation": "tanh",
            "alpha": 1e-5,
            "learning_rate_init": 1e-3
        }

    clf = MLPClassifier(
        hidden_layer_sizes=tuple(best_params.get("hidden_layer_sizes", (64, 32))),
        activation=str(best_params.get("activation", "relu")),
        alpha=float(best_params.get("alpha", 1e-5)),
        learning_rate_init=float(best_params.get("learning_rate_init", 1e-3)),
        max_iter=4000,
        early_stopping=True,
        n_iter_no_change=20,
        random_state=random_state
    )

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", clf)
    ])
    return pipe



def build_scouting_table(df, features, id_cols, target, fitted_model, model_name, top_n=50):
   
    X = df[features].copy()
    y = df[target].astype(int).copy()

    fitted_model.fit(X, y)
    proba_1 = fitted_model.predict_proba(X)[:, 1]
    pred = (proba_1 >= 0.5).astype(int)

    out = df[id_cols + [target]].copy()
    out["proba_1"] = proba_1
    out["pred"] = pred

    out = out.sort_values("proba_1", ascending=False).reset_index(drop=True)
    out.insert(0, "rank", np.arange(1, len(out) + 1))
    out.insert(1, "model", model_name)

    return out.head(top_n), out


#  Consensus ranking across the 3 models


def consensus_rank(tables_dict, id_cols, method="mean_rank"):
    

    base = None

    frames = []
    for mname, t in tables_dict.items():
        tmp = t[id_cols + ["proba_1"]].copy()
        tmp = tmp.rename(columns={"proba_1": f"proba_1_{mname}"})

        if base is None:
            base = tmp[id_cols].copy()

        frames.append(tmp)

    merged = frames[0]
    for i in range(1, len(frames)):
        merged = merged.merge(frames[i], on=id_cols, how="inner")

    proba_cols = [c for c in merged.columns if c.startswith("proba_1_")]

    if method == "mean_rank":
        for c in proba_cols:
            merged[f"rank_{c}"] = merged[c].rank(ascending=False, method="average")
        rank_cols = [c for c in merged.columns if c.startswith("rank_proba_1_")]
        merged["consensus_score"] = merged[rank_cols].mean(axis=1)
        merged = merged.sort_values("consensus_score", ascending=True)

    elif method == "mean_proba":
        merged["consensus_score"] = merged[proba_cols].mean(axis=1)
        merged = merged.sort_values("consensus_score", ascending=False)

    elif method == "zscore_proba":
        zcols = []
        for c in proba_cols:
            z = (merged[c] - merged[c].mean()) / (merged[c].std(ddof=0) + 1e-9)
            zname = f"z_{c}"
            merged[zname] = z
            zcols.append(zname)
        merged["consensus_score"] = merged[zcols].mean(axis=1)
        merged = merged.sort_values("consensus_score", ascending=False)

    else:
        raise ValueError("Unknown method. Use mean_rank, mean_proba, or zscore_proba")

    merged = merged.reset_index(drop=True)
    merged.insert(0, "consensus_rank", np.arange(1, len(merged) + 1))
    return merged


#  Permutation importance with two scorers:
#     ROC AUC 
#     NDCG@20 

def ndcg20_scorer(estimator, X, y):
    proba = estimator.predict_proba(X)[:, 1]
    return ndcg_at_k(y, proba, k=20)

def permutation_importance_table(model, X_test, y_test, feature_names, scoring, n_repeats=20, random_state=42):
    """
    Returns dataframe with mean and std permutation importance.
    
    """
    result = permutation_importance(
        model, X_test, y_test,
        scoring=scoring,
        n_repeats=n_repeats,
        random_state=random_state,
        n_jobs=-1
    )

    imp = pd.DataFrame({
        "feature": feature_names,
        "importance_mean": result.importances_mean,
        "importance_std": result.importances_std
    }).sort_values("importance_mean", ascending=False).reset_index(drop=True)

    return imp


#  SHAP for Logistic and XGBoost


def shap_for_logistic(pipe, X_background, X_explain, feature_names, max_display=20):
    
    
    pre = Pipeline(pipe.steps[:-1])
    clf = pipe.named_steps["clf"]

    Xb = pre.fit_transform(X_background)
    Xe = pre.transform(X_explain)

    masker = shap.maskers.Independent(Xb)
    explainer = shap.LinearExplainer(clf, masker)
    shap_values = explainer.shap_values(Xe)

    shap.summary_plot(shap_values, features=Xe, feature_names=feature_names, max_display=max_display)
    return shap_values


def shap_for_xgb(pipe, X_background, X_explain, feature_names, max_display=20):
    
    

    pre = Pipeline(pipe.steps[:-1])
    clf = pipe.named_steps["clf"]

    Xb = pre.fit_transform(X_background)
    Xe = pre.transform(X_explain)

    explainer = shap.TreeExplainer(clf)
    shap_values = explainer.shap_values(Xe)

    shap.summary_plot(shap_values, features=Xe, feature_names=feature_names, max_display=max_display)
    return shap_values

# %%
ID_COLS = ["Player", "Season", "Team", "Role"]
TARGET = "Tier_league"


BEST_OFF_LOG = {"C": 1.0, "l1_ratio": 1.0}   
BEST_OFF_XGB = {
    "colsample_bytree": 1.0,
    "learning_rate": 0.1,
    "max_depth": 2,
    "min_child_weight": 1,
    "n_estimators": 200,
    "subsample": 0.8
}
BEST_OFF_MLP = {
    "activation": "tanh",
    "alpha": 1e-5,
    "hidden_layer_sizes": (128,),
    "learning_rate_init": 1e-3
}


BEST_DEF_LOG = {"C": 0.01, "l1_ratio": 0.0}  
BEST_DEF_XGB = {
    "colsample_bytree": 0.9,
    "learning_rate": 0.1,
    "max_depth": 3,
    "min_child_weight": 1,
    "n_estimators": 400,
    "subsample": 0.8
}
BEST_DEF_MLP = {
    "activation": "tanh",
    "alpha": 1e-5,
    "hidden_layer_sizes": (64, 32),
    "learning_rate_init": 1e-3
}

# %%
off_log = build_logistic(BEST_OFF_LOG)
off_xgb = build_xgb(BEST_OFF_XGB)
off_mlp = build_mlp(BEST_OFF_MLP)

def_log = build_logistic(BEST_DEF_LOG)
def_xgb = build_xgb(BEST_DEF_XGB)
def_mlp = build_mlp(BEST_DEF_MLP)

# %% [markdown]
# Consensus Ranking 3 models and probabilities

# %%
TOP_N = 50

off_top_log, off_full_log = build_scouting_table(off_mid, FEATURES_OFF, ID_COLS, TARGET, off_log, "OFF_MID Logistic", top_n=TOP_N)
off_top_xgb, off_full_xgb = build_scouting_table(off_mid, FEATURES_OFF, ID_COLS, TARGET, off_xgb, "OFF_MID XGBoost", top_n=TOP_N)
off_top_mlp, off_full_mlp = build_scouting_table(off_mid, FEATURES_OFF, ID_COLS, TARGET, off_mlp, "OFF_MID MLP", top_n=TOP_N)

def_top_log, def_full_log = build_scouting_table(def_mid, FEATURES_DEF, ID_COLS, TARGET, def_log, "DEF_MID Logistic", top_n=TOP_N)
def_top_xgb, def_full_xgb = build_scouting_table(def_mid, FEATURES_DEF, ID_COLS, TARGET, def_xgb, "DEF_MID XGBoost", top_n=TOP_N)
def_top_mlp, def_full_mlp = build_scouting_table(def_mid, FEATURES_DEF, ID_COLS, TARGET, def_mlp, "DEF_MID MLP", top_n=TOP_N)

off_full_log.to_csv("OFF_MID_logistic_scouting.csv", index=False)
off_full_xgb.to_csv("OFF_MID_xgb_scouting.csv", index=False)
off_full_mlp.to_csv("OFF_MID_mlp_scouting.csv", index=False)

def_full_log.to_csv("DEF_MID_logistic_scouting.csv", index=False)
def_full_xgb.to_csv("DEF_MID_xgb_scouting.csv", index=False)
def_full_mlp.to_csv("DEF_MID_mlp_scouting.csv", index=False)

off_top_log, off_top_xgb, off_top_mlp, def_top_log, def_top_xgb, def_top_mlp
# Out:
# C:\Users\jsava\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\jsava\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# (    rank             model               Player     Season           Team  \
#  0      1  OFF_MID Logistic               Neymar  2017-2018      Paris S-G
#  1      2  OFF_MID Logistic               Neymar  2018-2019      Paris S-G
#  2      3  OFF_MID Logistic               Neymar  2019-2020      Paris S-G
#  3      4  OFF_MID Logistic       Javier Pastore  2017-2018      Paris S-G
#  4      5  OFF_MID Logistic       Julian Draxler  2017-2018      Paris S-G
#  5      6  OFF_MID Logistic         Moussa Diaby  2018-2019      Paris S-G
#  6      7  OFF_MID Logistic    Aleksandr Golovin  2020-2021         Monaco
#  7      8  OFF_MID Logistic      Florian Thauvin  2017-2018      Marseille
#  8      9  OFF_MID Logistic       Julian Draxler  2019-2020      Paris S-G
#  9     10  OFF_MID Logistic       Jonathan Ikone  2019-2020          Lille
#  10    11  OFF_MID Logistic        Maxwel Cornet  2018-2019           Lyon
#  11    12  OFF_MID Logistic         Nicolas Pépé  2018-2019          Lille
#  12    13  OFF_MID Logistic       Julian Draxler  2018-2019      Paris S-G
#  13    14  OFF_MID Logistic        Houssem Aouar  2017-2018           Lyon
#  14    15  OFF_MID Logistic       Martin Terrier  2018-2019           Lyon
#  15    16  OFF_MID Logistic               Neymar  2020-2021      Paris S-G
#  16    17  OFF_MID Logistic          Nabil Fekir  2018-2019           Lyon
#  17    18  OFF_MID Logistic       Rachid Ghezzal  2017-2018         Monaco
#  18    19  OFF_MID Logistic        Houssem Aouar  2019-2020           Lyon
#  19    20  OFF_MID Logistic          Lovro Majer  2021-2022         Rennes
#  20    21  OFF_MID Logistic          Nabil Fekir  2017-2018           Lyon
#  21    22  OFF_MID Logistic     Giovani Lo Celso  2017-2018      Paris S-G
#  22    23  OFF_MID Logistic        Pablo Sarabia  2020-2021      Paris S-G
#  23    24  OFF_MID Logistic       Julian Draxler  2020-2021      Paris S-G
#  24    25  OFF_MID Logistic       Yassine Benzia  2017-2018          Lille
#  25    26  OFF_MID Logistic        Lucas Paquetá  2021-2022           Lyon
#  26    27  OFF_MID Logistic          Keita Baldé  2017-2018         Monaco
#  27    28  OFF_MID Logistic       Martin Terrier  2021-2022         Rennes
#  28    29  OFF_MID Logistic       Dango Ouattara  2021-2022        Lorient
#  29    30  OFF_MID Logistic       Jonathan Bamba  2017-2018  Saint-Étienne
#  30    31  OFF_MID Logistic        Houssem Aouar  2020-2021           Lyon
#  31    32  OFF_MID Logistic   Kamaldeen Sulemana  2021-2022         Rennes
#  32    33  OFF_MID Logistic        Pablo Sarabia  2019-2020      Paris S-G
#  33    34  OFF_MID Logistic        Houssem Aouar  2018-2019           Lyon
#  34    35  OFF_MID Logistic       Jonathan Ikone  2018-2019          Lille
#  35    36  OFF_MID Logistic         Thomas Lemar  2017-2018         Monaco
#  36    37  OFF_MID Logistic               Malcom  2017-2018       Bordeaux
#  37    38  OFF_MID Logistic        Maxwel Cornet  2019-2020           Lyon
#  38    39  OFF_MID Logistic         Timothy Weah  2021-2022          Lille
#  39    40  OFF_MID Logistic          David Costa  2021-2022           Lens
#  40    41  OFF_MID Logistic        Arnaud Nordin  2018-2019  Saint-Étienne
#  41    42  OFF_MID Logistic       Angelo Fulgini  2017-2018         Angers
#  42    43  OFF_MID Logistic     Adrien Thomasson  2021-2022     Strasbourg
#  43    44  OFF_MID Logistic  Konrad De La Fuente  2021-2022      Marseille
#  44    45  OFF_MID Logistic      Myziane Maolida  2018-2019           Nice
#  45    46  OFF_MID Logistic        Maxwel Cornet  2017-2018           Lyon
#  46    47  OFF_MID Logistic       Jonathan Bamba  2018-2019          Lille
#  47    48  OFF_MID Logistic    Aleksandr Golovin  2021-2022         Monaco
#  48    49  OFF_MID Logistic      Myziane Maolida  2019-2020           Nice
#  49    50  OFF_MID Logistic       Martin Terrier  2020-2021         Rennes
#
#     Role  Tier_league   proba_1  pred
#  0    LW            1  1.000000     1
#  1    LW            1  1.000000     1
#  2    LW            1  0.999856     1
#  3    AM            1  0.999519     1
#  4    LW            1  0.999192     1
#  5    RW            1  0.998135     1
#  6    AM            1  0.997122     1
#  7    RW            1  0.996330     1
#  8    LW            1  0.995991     1
#  9    RW            1  0.992280     1
#  10   LW            1  0.988456     1
#  11   RW            1  0.988250     1
#  12   LW            1  0.987785     1
#  13   AM            1  0.987311     1
#  14   LW            0  0.987070     1
#  15   LW            1  0.985202     1
#  16   AM            1  0.984387     1
#  17   RW            1  0.980059     1
#  18   AM            1  0.976330     1
#  19   AM            1  0.971834     1
#  20   AM            1  0.965928     1
#  21   AM            1  0.955519     1
#  22   RW            1  0.950565     1
#  23   LW            1  0.949137     1
#  24   AM            0  0.948995     1
#  25   AM            1  0.943685     1
#  26   LW            1  0.943353     1
#  27   LW            1  0.938867     1
#  28   RW            1  0.933350     1
#  29   LW            1  0.928047     1
#  30   AM            1  0.925478     1
#  31   RW            0  0.922708     1
#  32   RW            1  0.912706     1
#  33   AM            1  0.899655     1
#  34   RW            1  0.892552     1
#  35   AM            1  0.890697     1
#  36   RW            0  0.884760     1
#  37   LW            1  0.879716     1
#  38   RW            1  0.859479     1
#  39   AM            0  0.838875     1
#  40   RW            0  0.838675     1
#  41   AM            0  0.823188     1
#  42   AM            0  0.812483     1
#  43   LW            0  0.801411     1
#  44   LW            0  0.791448     1
#  45   LW            0  0.790669     1
#  46   LW            1  0.789613     1
#  47   AM            1  0.782287     1
#  48   LW            0  0.758282     1
#  49   LW            1  0.757296     1  ,
#      rank            model               Player     Season         Team Role  \
#  0      1  OFF_MID XGBoost         Nicolas Pépé  2018-2019        Lille   RW
#  1      2  OFF_MID XGBoost               Neymar  2018-2019    Paris S-G   LW
#  2      3  OFF_MID XGBoost       Jonathan Ikone  2019-2020        Lille   RW
#  3      4  OFF_MID XGBoost               Neymar  2017-2018    Paris S-G   LW
#  4      5  OFF_MID XGBoost          Nabil Fekir  2018-2019         Lyon   AM
#  5      6  OFF_MID XGBoost       Julian Draxler  2017-2018    Paris S-G   LW
#  6      7  OFF_MID XGBoost      Florian Thauvin  2017-2018    Marseille   RW
#  7      8  OFF_MID XGBoost      Florian Thauvin  2018-2019    Marseille   RW
#  8      9  OFF_MID XGBoost     Giovani Lo Celso  2017-2018    Paris S-G   AM
#  9     10  OFF_MID XGBoost       Jonathan Ikone  2018-2019        Lille   RW
#  10    11  OFF_MID XGBoost       Julian Draxler  2018-2019    Paris S-G   LW
#  11    12  OFF_MID XGBoost        Houssem Aouar  2020-2021         Lyon   AM
#  12    13  OFF_MID XGBoost    Aleksandr Golovin  2020-2021       Monaco   AM
#  13    14  OFF_MID XGBoost               Neymar  2020-2021    Paris S-G   LW
#  14    15  OFF_MID XGBoost        Houssem Aouar  2019-2020         Lyon   AM
#  15    16  OFF_MID XGBoost         Moussa Diaby  2018-2019    Paris S-G   RW
#  16    17  OFF_MID XGBoost        Maxwel Cornet  2018-2019         Lyon   LW
#  17    18  OFF_MID XGBoost         Thomas Lemar  2017-2018       Monaco   AM
#  18    19  OFF_MID XGBoost        Lucas Paquetá  2020-2021         Lyon   AM
#  19    20  OFF_MID XGBoost        Houssem Aouar  2018-2019         Lyon   AM
#  20    21  OFF_MID XGBoost        Houssem Aouar  2017-2018         Lyon   AM
#  21    22  OFF_MID XGBoost       Jonathan Ikone  2020-2021        Lille   RW
#  22    23  OFF_MID XGBoost       Javier Pastore  2017-2018    Paris S-G   AM
#  23    24  OFF_MID XGBoost       Rachid Ghezzal  2017-2018       Monaco   RW
#  24    25  OFF_MID XGBoost        Pablo Sarabia  2020-2021    Paris S-G   RW
#  25    26  OFF_MID XGBoost          Nabil Fekir  2017-2018         Lyon   AM
#  26    27  OFF_MID XGBoost        Pablo Sarabia  2019-2020    Paris S-G   RW
#  27    28  OFF_MID XGBoost       Julian Draxler  2019-2020    Paris S-G   LW
#  28    29  OFF_MID XGBoost               Neymar  2019-2020    Paris S-G   LW
#  29    30  OFF_MID XGBoost       Jonathan Ikone  2017-2018  Montpellier   RW
#  30    31  OFF_MID XGBoost        Lucas Paquetá  2021-2022         Lyon   AM
#  31    32  OFF_MID XGBoost        Houssem Aouar  2021-2022         Lyon   AM
#  32    33  OFF_MID XGBoost     Armand Lauriente  2020-2021      Lorient   RW
#  33    34  OFF_MID XGBoost          Lovro Majer  2021-2022       Rennes   AM
#  34    35  OFF_MID XGBoost       Martin Terrier  2021-2022       Rennes   LW
#  35    36  OFF_MID XGBoost        Maxwel Cornet  2019-2020         Lyon   LW
#  36    37  OFF_MID XGBoost     Armand Lauriente  2021-2022      Lorient   RW
#  37    38  OFF_MID XGBoost          Keita Baldé  2017-2018       Monaco   LW
#  38    39  OFF_MID XGBoost             Raphinha  2019-2020       Rennes   LW
#  39    40  OFF_MID XGBoost       Dango Ouattara  2021-2022      Lorient   RW
#  40    41  OFF_MID XGBoost       Martin Terrier  2020-2021       Rennes   LW
#  41    42  OFF_MID XGBoost       Jonathan Ikone  2021-2022        Lille   RW
#  42    43  OFF_MID XGBoost       Julian Draxler  2020-2021    Paris S-G   LW
#  43    44  OFF_MID XGBoost        Kevin Volland  2020-2021       Monaco   AM
#  44    45  OFF_MID XGBoost         Ismaila Sarr  2018-2019       Rennes   RW
#  45    46  OFF_MID XGBoost    Aleksandr Golovin  2019-2020       Monaco   AM
#  46    47  OFF_MID XGBoost  Allan Saint-Maximin  2017-2018      2 Teams   LW
#  47    48  OFF_MID XGBoost        Lucas Ocampos  2017-2018    Marseille   LW
#  48    49  OFF_MID XGBoost       Jonathan Bamba  2018-2019        Lille   LW
#  49    50  OFF_MID XGBoost        Maxwel Cornet  2020-2021         Lyon   LW
#
#      Tier_league   proba_1  pred
#  0             1  0.993923     1
#  1             1  0.992537     1
#  2             1  0.988430     1
#  3             1  0.988103     1
#  4             1  0.987612     1
#  5             1  0.982837     1
#  6             1  0.982508     1
#  7             1  0.973875     1
#  8             1  0.970534     1
#  9             1  0.968421     1
#  10            1  0.967080     1
#  11            1  0.961784     1
#  12            1  0.955702     1
#  13            1  0.951761     1
#  14            1  0.944322     1
#  15            1  0.940725     1
#  16            1  0.937564     1
#  17            1  0.920451     1
#  18            1  0.920072     1
#  19            1  0.917430     1
#  20            1  0.917363     1
#  21            1  0.916852     1
#  22            1  0.915067     1
#  23            1  0.911218     1
#  24            1  0.909369     1
#  25            1  0.908635     1
#  26            1  0.900675     1
#  27            1  0.896915     1
#  28            1  0.895161     1
#  29            1  0.889299     1
#  30            1  0.883064     1
#  31            1  0.879365     1
#  32            1  0.877564     1
#  33            1  0.877131     1
#  34            1  0.870749     1
#  35            1  0.868532     1
#  36            1  0.866052     1
#  37            1  0.863987     1
#  38            1  0.860092     1
#  39            1  0.855859     1
#  40            1  0.850432     1
#  41            1  0.846053     1
#  42            1  0.842636     1
#  43            1  0.837591     1
#  44            1  0.832055     1
#  45            1  0.829190     1
#  46            1  0.815485     1
#  47            1  0.809832     1
#  48            1  0.794546     1
#  49            1  0.779938     1  ,
#      rank        model               Player     Season           Team Role  \
#  0      1  OFF_MID MLP          David Costa  2021-2022           Lens   AM
#  1      2  OFF_MID MLP      Florian Thauvin  2017-2018      Marseille   RW
#  2      3  OFF_MID MLP               Malcom  2017-2018       Bordeaux   RW
#  3      4  OFF_MID MLP          Lovro Majer  2021-2022         Rennes   AM
#  4      5  OFF_MID MLP         Moussa Diaby  2018-2019      Paris S-G   RW
#  5      6  OFF_MID MLP               Neymar  2018-2019      Paris S-G   LW
#  6      7  OFF_MID MLP        Maxwel Cornet  2018-2019           Lyon   LW
#  7      8  OFF_MID MLP  Jeff Reine-Adélaïde  2019-2020        2 Teams   AM
#  8      9  OFF_MID MLP               Neymar  2019-2020      Paris S-G   LW
#  9     10  OFF_MID MLP       Julian Draxler  2020-2021      Paris S-G   LW
#  10    11  OFF_MID MLP               Neymar  2017-2018      Paris S-G   LW
#  11    12  OFF_MID MLP         Yusuf Yazıcı  2020-2021          Lille   AM
#  12    13  OFF_MID MLP       Jonathan Ikone  2019-2020          Lille   RW
#  13    14  OFF_MID MLP       Julian Draxler  2017-2018      Paris S-G   LW
#  14    15  OFF_MID MLP        Houssem Aouar  2020-2021           Lyon   AM
#  15    16  OFF_MID MLP         Nicolas Pépé  2018-2019          Lille   RW
#  16    17  OFF_MID MLP  Allan Saint-Maximin  2017-2018        2 Teams   LW
#  17    18  OFF_MID MLP         Sofiane Diop  2021-2022         Monaco   LW
#  18    19  OFF_MID MLP       Adil Aouchiche  2020-2021  Saint-Étienne   AM
#  19    20  OFF_MID MLP           Adam Ounas  2019-2020           Nice   RW
#  20    21  OFF_MID MLP       Martin Terrier  2021-2022         Rennes   LW
#  21    22  OFF_MID MLP       Jonathan Ikone  2018-2019          Lille   RW
#  22    23  OFF_MID MLP  Konrad De La Fuente  2021-2022      Marseille   LW
#  23    24  OFF_MID MLP         Yann Karamoh  2018-2019       Bordeaux   LW
#  24    25  OFF_MID MLP    Aleksandr Golovin  2020-2021         Monaco   AM
#  25    26  OFF_MID MLP     Javairô Dilrosun  2021-2022       Bordeaux   LW
#  26    27  OFF_MID MLP       Martin Terrier  2020-2021         Rennes   LW
#  27    28  OFF_MID MLP          Moses Simon  2021-2022         Nantes   LW
#  28    29  OFF_MID MLP         Timothy Weah  2021-2022          Lille   RW
#  29    30  OFF_MID MLP          Amine Harit  2021-2022      Marseille   AM
#  30    31  OFF_MID MLP          Nabil Fekir  2018-2019           Lyon   AM
#  31    32  OFF_MID MLP        Maxwel Cornet  2017-2018           Lyon   LW
#  32    33  OFF_MID MLP       Yannis Salibur  2018-2019  Saint-Étienne   RW
#  33    34  OFF_MID MLP        Houssem Aouar  2017-2018           Lyon   AM
#  34    35  OFF_MID MLP       Javier Pastore  2017-2018      Paris S-G   AM
#  35    36  OFF_MID MLP          Moses Simon  2019-2020         Nantes   LW
#  36    37  OFF_MID MLP             Raphinha  2019-2020         Rennes   LW
#  37    38  OFF_MID MLP               Neymar  2020-2021      Paris S-G   LW
#  38    39  OFF_MID MLP      Myziane Maolida  2019-2020           Nice   LW
#  39    40  OFF_MID MLP          Jeremy Doku  2020-2021         Rennes   LW
#  40    41  OFF_MID MLP          Keita Baldé  2017-2018         Monaco   LW
#  41    42  OFF_MID MLP     Armand Lauriente  2020-2021        Lorient   RW
#  42    43  OFF_MID MLP         Thomas Lemar  2017-2018         Monaco   AM
#  43    44  OFF_MID MLP      Florian Thauvin  2018-2019      Marseille   RW
#  44    45  OFF_MID MLP   Kamaldeen Sulemana  2021-2022         Rennes   RW
#  45    46  OFF_MID MLP           Remi Oudin  2019-2020        2 Teams   AM
#  46    47  OFF_MID MLP    Aleksandr Golovin  2021-2022         Monaco   AM
#  47    48  OFF_MID MLP      Myziane Maolida  2020-2021           Nice   LW
#  48    49  OFF_MID MLP       Jonathan Bamba  2017-2018  Saint-Étienne   LW
#  49    50  OFF_MID MLP          Samuel Kalu  2018-2019       Bordeaux   RW
#
#      Tier_league   proba_1  pred
#  0             0  0.874785     1
#  1             1  0.870397     1
#  2             0  0.834219     1
#  3             1  0.833093     1
#  4             1  0.832037     1
#  5             1  0.826220     1
#  6             1  0.811252     1
#  7             0  0.806494     1
#  8             1  0.801101     1
#  9             1  0.796729     1
#  10            1  0.795836     1
#  11            0  0.795136     1
#  12            1  0.793922     1
#  13            1  0.793473     1
#  14            1  0.792713     1
#  15            1  0.788368     1
#  16            1  0.785377     1
#  17            0  0.776258     1
#  18            0  0.773375     1
#  19            0  0.773055     1
#  20            1  0.771043     1
#  21            1  0.763755     1
#  22            0  0.759847     1
#  23            0  0.758701     1
#  24            1  0.756089     1
#  25            0  0.748952     1
#  26            1  0.740854     1
#  27            0  0.737419     1
#  28            1  0.736777     1
#  29            0  0.736485     1
#  30            1  0.733406     1
#  31            0  0.732136     1
#  32            0  0.720758     1
#  33            1  0.714350     1
#  34            1  0.713719     1
#  35            0  0.710083     1
#  36            1  0.709287     1
#  37            1  0.708769     1
#  38            0  0.705608     1
#  39            1  0.704581     1
#  40            1  0.704215     1
#  41            1  0.700145     1
#  42            1  0.696611     1
#  43            1  0.696364     1
#  44            0  0.694499     1
#  45            0  0.691633     1
#  46            1  0.686243     1
#  47            0  0.684991     1
#  48            1  0.684508     1
#  49            0  0.680129     1  ,
#      rank             model                      Player     Season       Team  \
#  0      1  DEF_MID Logistic               Adrien Rabiot  2018-2019  Paris S-G
#  1      2  DEF_MID Logistic              Marco Verratti  2017-2018  Paris S-G
#  2      3  DEF_MID Logistic              Marco Verratti  2018-2019  Paris S-G
#  3      4  DEF_MID Logistic               Adrien Rabiot  2017-2018  Paris S-G
#  4      5  DEF_MID Logistic              Marco Verratti  2019-2020  Paris S-G
#  5      6  DEF_MID Logistic             Tanguy Ndombele  2018-2019       Lyon
#  6      7  DEF_MID Logistic               Yves Bissouma  2017-2018      Lille
#  7      8  DEF_MID Logistic              Marco Verratti  2021-2022  Paris S-G
#  8      9  DEF_MID Logistic                Jordan Ferri  2017-2018       Lyon
#  9     10  DEF_MID Logistic              Marco Verratti  2020-2021  Paris S-G
#  10    11  DEF_MID Logistic             Leandro Paredes  2019-2020  Paris S-G
#  11    12  DEF_MID Logistic             Leandro Paredes  2020-2021  Paris S-G
#  12    13  DEF_MID Logistic         Aurélien Tchouaméni  2021-2022     Monaco
#  13    14  DEF_MID Logistic             Tanguy Ndombele  2017-2018    2 Teams
#  14    15  DEF_MID Logistic                  Marquinhos  2018-2019  Paris S-G
#  15    16  DEF_MID Logistic                Maxime Lopez  2017-2018  Marseille
#  16    17  DEF_MID Logistic              Renato Sanches  2021-2022      Lille
#  17    18  DEF_MID Logistic                  Marquinhos  2019-2020  Paris S-G
#  18    19  DEF_MID Logistic             Khéphren Thuram  2021-2022       Nice
#  19    20  DEF_MID Logistic             Leandro Paredes  2021-2022  Paris S-G
#  20    21  DEF_MID Logistic                Maxime Lopez  2018-2019  Marseille
#  21    22  DEF_MID Logistic             Tanguy Ndombele  2021-2022       Lyon
#  22    23  DEF_MID Logistic                     Fabinho  2017-2018     Monaco
#  23    24  DEF_MID Logistic              Renato Sanches  2020-2021      Lille
#  24    25  DEF_MID Logistic            Valentin Rongier  2021-2022  Marseille
#  25    26  DEF_MID Logistic             Ibrahim Sangaré  2018-2019   Toulouse
#  26    27  DEF_MID Logistic             Ibrahim Sangaré  2017-2018   Toulouse
#  27    28  DEF_MID Logistic            Mattéo Guendouzi  2021-2022  Marseille
#  28    29  DEF_MID Logistic                 Yacine Adli  2020-2021   Bordeaux
#  29    30  DEF_MID Logistic             Khéphren Thuram  2020-2021       Nice
#  30    31  DEF_MID Logistic  Andre-Frank Zambo Anguissa  2017-2018  Marseille
#  31    32  DEF_MID Logistic             Leandro Paredes  2018-2019  Paris S-G
#  32    33  DEF_MID Logistic                 Yacine Adli  2019-2020   Bordeaux
#  33    34  DEF_MID Logistic                Amadou Onana  2021-2022      Lille
#  34    35  DEF_MID Logistic             Youssouf Fofana  2021-2022     Monaco
#  35    36  DEF_MID Logistic             Youri Tielemans  2017-2018     Monaco
#  36    37  DEF_MID Logistic                 Yacine Adli  2021-2022   Bordeaux
#  37    38  DEF_MID Logistic                Mario Lemina  2021-2022       Nice
#  38    39  DEF_MID Logistic             Pape Matar Sarr  2020-2021       Metz
#  39    40  DEF_MID Logistic                Flavien Tait  2021-2022     Rennes
#  40    41  DEF_MID Logistic             Youri Tielemans  2018-2019     Monaco
#  41    42  DEF_MID Logistic                Maxime Lopez  2019-2020  Marseille
#  42    43  DEF_MID Logistic         Aurélien Tchouaméni  2020-2021     Monaco
#  43    44  DEF_MID Logistic             Ibrahim Sangaré  2019-2020   Toulouse
#  44    45  DEF_MID Logistic                  Jean Onana  2021-2022    2 Teams
#  45    46  DEF_MID Logistic            Valentin Rongier  2019-2020    2 Teams
#  46    47  DEF_MID Logistic             Azzedine Ounahi  2021-2022     Angers
#  47    48  DEF_MID Logistic                Flavien Tait  2018-2019     Angers
#  48    49  DEF_MID Logistic                   Jean Seri  2017-2018       Nice
#  49    50  DEF_MID Logistic                 Youcef Atal  2018-2019       Nice
#
#     Role  Tier_league   proba_1  pred
#  0    RM            1  0.986415     1
#  1    CM            1  0.973195     1
#  2    CM            1  0.948831     1
#  3    RM            1  0.942311     1
#  4    CM            1  0.942064     1
#  5    CM            1  0.937956     1
#  6    DM            1  0.926517     1
#  7    CM            1  0.917267     1
#  8    CM            0  0.912437     1
#  9    CM            1  0.910230     1
#  10   DM            1  0.898483     1
#  11   DM            1  0.896870     1
#  12   DM            1  0.878508     1
#  13   CM            1  0.864490     1
#  14   DM            1  0.858575     1
#  15   CM            1  0.856122     1
#  16   CM            1  0.851453     1
#  17   DM            1  0.849299     1
#  18   CM            1  0.848861     1
#  19   DM            1  0.838467     1
#  20   CM            1  0.831738     1
#  21   CM            0  0.825160     1
#  22   CM            1  0.818329     1
#  23   CM            1  0.792856     1
#  24   CM            1  0.785902     1
#  25   DM            1  0.777858     1
#  26   DM            0  0.766886     1
#  27   CM            1  0.766846     1
#  28   CM            0  0.761788     1
#  29   CM            1  0.761670     1
#  30   DM            1  0.760345     1
#  31   DM            1  0.751515     1
#  32   CM            0  0.750947     1
#  33   DM            1  0.741936     1
#  34   DM            1  0.714209     1
#  35   CM            1  0.713593     1
#  36   CM            1  0.709901     1
#  37   DM            1  0.709103     1
#  38   CM            1  0.707146     1
#  39   CM            0  0.703116     1
#  40   CM            1  0.702295     1
#  41   CM            1  0.700486     1
#  42   DM            1  0.698794     1
#  43   DM            1  0.697251     1
#  44   DM            0  0.695994     1
#  45   CM            1  0.690686     1
#  46   CM            0  0.688822     1
#  47   CM            0  0.687832     1
#  48   DM            0  0.686403     1
#  49   RM            0  0.679439     1  ,
#      rank            model                      Player     Season       Team  \
#  0      1  DEF_MID XGBoost               Yves Bissouma  2017-2018      Lille
#  1      2  DEF_MID XGBoost               Adrien Rabiot  2018-2019  Paris S-G
#  2      3  DEF_MID XGBoost               Adrien Rabiot  2017-2018  Paris S-G
#  3      4  DEF_MID XGBoost             Khéphren Thuram  2021-2022       Nice
#  4      5  DEF_MID XGBoost                     Fabinho  2017-2018     Monaco
#  5      6  DEF_MID XGBoost         Aurélien Tchouaméni  2021-2022     Monaco
#  6      7  DEF_MID XGBoost             Tanguy Ndombele  2018-2019       Lyon
#  7      8  DEF_MID XGBoost             Leandro Paredes  2020-2021  Paris S-G
#  8      9  DEF_MID XGBoost                Mario Lemina  2021-2022       Nice
#  9     10  DEF_MID XGBoost             Ibrahim Sangaré  2018-2019   Toulouse
#  10    11  DEF_MID XGBoost            Valentin Rongier  2021-2022  Marseille
#  11    12  DEF_MID XGBoost              Marco Verratti  2021-2022  Paris S-G
#  12    13  DEF_MID XGBoost             Ibrahim Sangaré  2019-2020   Toulouse
#  13    14  DEF_MID XGBoost         Aurélien Tchouaméni  2020-2021     Monaco
#  14    15  DEF_MID XGBoost              Renato Sanches  2020-2021      Lille
#  15    16  DEF_MID XGBoost  Andre-Frank Zambo Anguissa  2017-2018  Marseille
#  16    17  DEF_MID XGBoost             Leandro Paredes  2021-2022  Paris S-G
#  17    18  DEF_MID XGBoost             Tanguy Ndombele  2017-2018    2 Teams
#  18    19  DEF_MID XGBoost              Marco Verratti  2018-2019  Paris S-G
#  19    20  DEF_MID XGBoost                  Marquinhos  2018-2019  Paris S-G
#  20    21  DEF_MID XGBoost                  Marquinhos  2019-2020  Paris S-G
#  21    22  DEF_MID XGBoost             Khéphren Thuram  2020-2021       Nice
#  22    23  DEF_MID XGBoost                Maxime Lopez  2018-2019  Marseille
#  23    24  DEF_MID XGBoost                Maxime Lopez  2017-2018  Marseille
#  24    25  DEF_MID XGBoost              Renato Sanches  2021-2022      Lille
#  25    26  DEF_MID XGBoost             Leandro Paredes  2019-2020  Paris S-G
#  26    27  DEF_MID XGBoost         Baptiste Santamaria  2021-2022     Rennes
#  27    28  DEF_MID XGBoost              Marco Verratti  2019-2020  Paris S-G
#  28    29  DEF_MID XGBoost            Valentin Rongier  2017-2018     Nantes
#  29    30  DEF_MID XGBoost                  Pape Gueye  2021-2022  Marseille
#  30    31  DEF_MID XGBoost             Youssouf Fofana  2021-2022     Monaco
#  31    32  DEF_MID XGBoost             Youssouf Fofana  2020-2021     Monaco
#  32    33  DEF_MID XGBoost             Youssouf Fofana  2019-2020    2 Teams
#  33    34  DEF_MID XGBoost             Pape Matar Sarr  2020-2021       Metz
#  34    35  DEF_MID XGBoost            Valentin Rongier  2019-2020    2 Teams
#  35    36  DEF_MID XGBoost              Renato Sanches  2019-2020      Lille
#  36    37  DEF_MID XGBoost                  Pape Gueye  2020-2021  Marseille
#  37    38  DEF_MID XGBoost               Lucas Tousart  2019-2020       Lyon
#  38    39  DEF_MID XGBoost              Marco Verratti  2020-2021  Paris S-G
#  39    40  DEF_MID XGBoost             Youri Tielemans  2017-2018     Monaco
#  40    41  DEF_MID XGBoost                Maxime Lopez  2019-2020  Marseille
#  41    42  DEF_MID XGBoost            Tiemoué Bakayoko  2019-2020     Monaco
#  42    43  DEF_MID XGBoost               Thiago Mendes  2017-2018      Lille
#  43    44  DEF_MID XGBoost            Valentin Rongier  2020-2021  Marseille
#  44    45  DEF_MID XGBoost               Lucien Agoume  2021-2022      Brest
#  45    46  DEF_MID XGBoost                        Xeka  2018-2019      Lille
#  46    47  DEF_MID XGBoost               Lucas Tousart  2018-2019       Lyon
#  47    48  DEF_MID XGBoost               Adrien Tameze  2017-2018       Nice
#  48    49  DEF_MID XGBoost                  Toma Bašić  2019-2020   Bordeaux
#  49    50  DEF_MID XGBoost             Youri Tielemans  2018-2019     Monaco
#
#     Role  Tier_league   proba_1  pred
#  0    DM            1  0.999650     1
#  1    RM            1  0.998532     1
#  2    RM            1  0.998202     1
#  3    CM            1  0.998106     1
#  4    CM            1  0.997452     1
#  5    DM            1  0.997266     1
#  6    CM            1  0.997112     1
#  7    DM            1  0.995881     1
#  8    DM            1  0.995780     1
#  9    DM            1  0.994606     1
#  10   CM            1  0.994386     1
#  11   CM            1  0.991664     1
#  12   DM            1  0.990319     1
#  13   DM            1  0.989376     1
#  14   CM            1  0.987637     1
#  15   DM            1  0.987109     1
#  16   DM            1  0.986525     1
#  17   CM            1  0.985942     1
#  18   CM            1  0.985624     1
#  19   DM            1  0.985467     1
#  20   DM            1  0.983302     1
#  21   CM            1  0.982752     1
#  22   CM            1  0.982398     1
#  23   CM            1  0.980317     1
#  24   CM            1  0.980261     1
#  25   DM            1  0.980078     1
#  26   DM            1  0.979677     1
#  27   CM            1  0.978908     1
#  28   CM            1  0.978703     1
#  29   DM            1  0.976954     1
#  30   DM            1  0.976735     1
#  31   DM            1  0.976588     1
#  32   DM            1  0.976037     1
#  33   CM            1  0.975047     1
#  34   CM            1  0.974327     1
#  35   CM            1  0.973930     1
#  36   DM            1  0.973834     1
#  37   CM            1  0.973743     1
#  38   CM            1  0.973351     1
#  39   CM            1  0.971860     1
#  40   CM            1  0.971797     1
#  41   DM            1  0.970960     1
#  42   DM            1  0.969506     1
#  43   CM            1  0.967833     1
#  44   DM            1  0.967598     1
#  45   CM            1  0.967561     1
#  46   CM            1  0.967112     1
#  47   DM            1  0.965873     1
#  48   CM            1  0.965248     1
#  49   CM            1  0.962769     1  ,
#      rank        model                      Player     Season       Team Role  \
#  0      1  DEF_MID MLP               Adrien Rabiot  2018-2019  Paris S-G   RM
#  1      2  DEF_MID MLP               Yves Bissouma  2017-2018      Lille   DM
#  2      3  DEF_MID MLP               Adrien Rabiot  2017-2018  Paris S-G   RM
#  3      4  DEF_MID MLP              Marco Verratti  2017-2018  Paris S-G   CM
#  4      5  DEF_MID MLP             Leandro Paredes  2020-2021  Paris S-G   DM
#  5      6  DEF_MID MLP             Tanguy Ndombele  2018-2019       Lyon   CM
#  6      7  DEF_MID MLP             Khéphren Thuram  2021-2022       Nice   CM
#  7      8  DEF_MID MLP         Aurélien Tchouaméni  2021-2022     Monaco   DM
#  8      9  DEF_MID MLP              Marco Verratti  2019-2020  Paris S-G   CM
#  9     10  DEF_MID MLP              Marco Verratti  2018-2019  Paris S-G   CM
#  10    11  DEF_MID MLP                  Marquinhos  2018-2019  Paris S-G   DM
#  11    12  DEF_MID MLP             Tanguy Ndombele  2017-2018    2 Teams   CM
#  12    13  DEF_MID MLP                Maxime Lopez  2018-2019  Marseille   CM
#  13    14  DEF_MID MLP              Marco Verratti  2020-2021  Paris S-G   CM
#  14    15  DEF_MID MLP              Marco Verratti  2021-2022  Paris S-G   CM
#  15    16  DEF_MID MLP                  Marquinhos  2019-2020  Paris S-G   DM
#  16    17  DEF_MID MLP             Khéphren Thuram  2020-2021       Nice   CM
#  17    18  DEF_MID MLP             Ibrahim Sangaré  2018-2019   Toulouse   DM
#  18    19  DEF_MID MLP             Leandro Paredes  2019-2020  Paris S-G   DM
#  19    20  DEF_MID MLP                Jordan Ferri  2017-2018       Lyon   CM
#  20    21  DEF_MID MLP            Valentin Rongier  2021-2022  Marseille   CM
#  21    22  DEF_MID MLP             Leandro Paredes  2021-2022  Paris S-G   DM
#  22    23  DEF_MID MLP                Maxime Lopez  2017-2018  Marseille   CM
#  23    24  DEF_MID MLP                     Fabinho  2017-2018     Monaco   CM
#  24    25  DEF_MID MLP             Tanguy Ndombele  2021-2022       Lyon   CM
#  25    26  DEF_MID MLP              Renato Sanches  2021-2022      Lille   CM
#  26    27  DEF_MID MLP                 Yacine Adli  2020-2021   Bordeaux   CM
#  27    28  DEF_MID MLP              Renato Sanches  2020-2021      Lille   CM
#  28    29  DEF_MID MLP             Pape Matar Sarr  2020-2021       Metz   CM
#  29    30  DEF_MID MLP             Youssouf Fofana  2021-2022     Monaco   DM
#  30    31  DEF_MID MLP         Aurélien Tchouaméni  2020-2021     Monaco   DM
#  31    32  DEF_MID MLP             Ibrahim Sangaré  2017-2018   Toulouse   DM
#  32    33  DEF_MID MLP  Andre-Frank Zambo Anguissa  2017-2018  Marseille   DM
#  33    34  DEF_MID MLP            Valentin Rongier  2019-2020    2 Teams   CM
#  34    35  DEF_MID MLP                Amadou Onana  2021-2022      Lille   DM
#  35    36  DEF_MID MLP             Youri Tielemans  2018-2019     Monaco   CM
#  36    37  DEF_MID MLP             Azzedine Ounahi  2021-2022     Angers   CM
#  37    38  DEF_MID MLP             Ibrahim Sangaré  2019-2020   Toulouse   DM
#  38    39  DEF_MID MLP            Mattéo Guendouzi  2021-2022  Marseille   CM
#  39    40  DEF_MID MLP                Maxime Lopez  2019-2020  Marseille   CM
#  40    41  DEF_MID MLP                Mario Lemina  2021-2022       Nice   DM
#  41    42  DEF_MID MLP             Leandro Paredes  2018-2019  Paris S-G   DM
#  42    43  DEF_MID MLP               Thiago Mendes  2017-2018      Lille   DM
#  43    44  DEF_MID MLP             Youri Tielemans  2017-2018     Monaco   CM
#  44    45  DEF_MID MLP              Danilo Barbosa  2019-2020       Nice   DM
#  45    46  DEF_MID MLP                  Jean Onana  2021-2022    2 Teams   DM
#  46    47  DEF_MID MLP              Soualiho Meïté  2017-2018    2 Teams   DM
#  47    48  DEF_MID MLP                 Yacine Adli  2019-2020   Bordeaux   CM
#  48    49  DEF_MID MLP            Valentin Rongier  2018-2019     Nantes   CM
#  49    50  DEF_MID MLP                  Toma Bašić  2019-2020   Bordeaux   CM
#
#      Tier_league   proba_1  pred
#  0             1  0.982584     1
#  1             1  0.964569     1
#  2             1  0.963588     1
#  3             1  0.946266     1
#  4             1  0.944773     1
#  5             1  0.938561     1
#  6             1  0.918501     1
#  7             1  0.916978     1
#  8             1  0.916667     1
#  9             1  0.911947     1
#  10            1  0.903889     1
#  11            1  0.885672     1
#  12            1  0.883334     1
#  13            1  0.880851     1
#  14            1  0.879387     1
#  15            1  0.875663     1
#  16            1  0.869039     1
#  17            1  0.858689     1
#  18            1  0.849279     1
#  19            0  0.837474     1
#  20            1  0.832971     1
#  21            1  0.831404     1
#  22            1  0.822180     1
#  23            1  0.818997     1
#  24            0  0.811304     1
#  25            1  0.794927     1
#  26            0  0.781190     1
#  27            1  0.775741     1
#  28            1  0.766959     1
#  29            1  0.762375     1
#  30            1  0.761773     1
#  31            0  0.757775     1
#  32            1  0.752362     1
#  33            1  0.724602     1
#  34            1  0.717187     1
#  35            1  0.705317     1
#  36            0  0.698926     1
#  37            1  0.681955     1
#  38            1  0.669124     1
#  39            1  0.649131     1
#  40            1  0.642433     1
#  41            1  0.640005     1
#  42            1  0.632685     1
#  43            1  0.615176     1
#  44            0  0.610889     1
#  45            0  0.562574     1
#  46            1  0.561206     1
#  47            0  0.556324     1
#  48            1  0.549481     1
#  49            1  0.522646     1  )

# %%
off_tables = {
    "Logistic": off_full_log,
    "XGB": off_full_xgb,
    "MLP": off_full_mlp
}

def_tables = {
    "Logistic": def_full_log,
    "XGB": def_full_xgb,
    "MLP": def_full_mlp
}

off_consensus = consensus_rank(off_tables, ID_COLS, method="mean_rank")
def_consensus = consensus_rank(def_tables, ID_COLS, method="mean_rank")

off_consensus.to_csv("OFF_MID_consensus_ranking.csv", index=False)
def_consensus.to_csv("DEF_MID_consensus_ranking.csv", index=False)

off_consensus.head(30), def_consensus.head(30)
# Out:
# (    consensus_rank             Player     Season       Team Role  \
#  0                1             Neymar  2018-2019  Paris S-G   LW
#  1                2             Neymar  2017-2018  Paris S-G   LW
#  2                3    Florian Thauvin  2017-2018  Marseille   RW
#  3                4     Julian Draxler  2017-2018  Paris S-G   LW
#  4                5     Jonathan Ikone  2019-2020      Lille   RW
#  5                6       Moussa Diaby  2018-2019  Paris S-G   RW
#  6                7       Nicolas Pépé  2018-2019      Lille   RW
#  7                8      Maxwel Cornet  2018-2019       Lyon   LW
#  8                9             Neymar  2019-2020  Paris S-G   LW
#  9               10  Aleksandr Golovin  2020-2021     Monaco   AM
#  10              11        Nabil Fekir  2018-2019       Lyon   AM
#  11              12        Lovro Majer  2021-2022     Rennes   AM
#  12              13      Houssem Aouar  2020-2021       Lyon   AM
#  13              14     Javier Pastore  2017-2018  Paris S-G   AM
#  14              15     Jonathan Ikone  2018-2019      Lille   RW
#  15              16             Neymar  2020-2021  Paris S-G   LW
#  16              17      Houssem Aouar  2017-2018       Lyon   AM
#  17              18     Julian Draxler  2020-2021  Paris S-G   LW
#  18              19     Julian Draxler  2018-2019  Paris S-G   LW
#  19              20     Martin Terrier  2021-2022     Rennes   LW
#  20              21     Rachid Ghezzal  2017-2018     Monaco   RW
#  21              22       Thomas Lemar  2017-2018     Monaco   AM
#  22              23        Keita Baldé  2017-2018     Monaco   LW
#  23              24    Florian Thauvin  2018-2019  Marseille   RW
#  24              25        David Costa  2021-2022       Lens   AM
#  25              26      Houssem Aouar  2018-2019       Lyon   AM
#  26              27     Martin Terrier  2020-2021     Rennes   LW
#  27              28             Malcom  2017-2018   Bordeaux   RW
#  28              29       Timothy Weah  2021-2022      Lille   RW
#  29              30      Houssem Aouar  2019-2020       Lyon   AM
#
#      proba_1_Logistic  proba_1_XGB  proba_1_MLP  rank_proba_1_Logistic  \
#  0           1.000000     0.992537     0.826220                    2.0
#  1           1.000000     0.988103     0.795836                    1.0
#  2           0.996330     0.982508     0.870397                    8.0
#  3           0.999192     0.982837     0.793473                    5.0
#  4           0.992280     0.988430     0.793922                   10.0
#  5           0.998135     0.940725     0.832037                    6.0
#  6           0.988250     0.993923     0.788368                   12.0
#  7           0.988456     0.937564     0.811252                   11.0
#  8           0.999856     0.895161     0.801101                    3.0
#  9           0.997122     0.955702     0.756089                    7.0
#  10          0.984387     0.987612     0.733406                   17.0
#  11          0.971834     0.877131     0.833093                   20.0
#  12          0.925478     0.961784     0.792713                   31.0
#  13          0.999519     0.915067     0.713719                    4.0
#  14          0.892552     0.968421     0.763755                   35.0
#  15          0.985202     0.951761     0.708769                   16.0
#  16          0.987311     0.917363     0.714350                   14.0
#  17          0.949137     0.842636     0.796729                   24.0
#  18          0.987785     0.967080     0.669508                   13.0
#  19          0.938867     0.870749     0.771043                   28.0
#  20          0.980059     0.911218     0.673968                   18.0
#  21          0.890697     0.920451     0.696611                   36.0
#  22          0.943353     0.863987     0.704215                   27.0
#  23          0.734776     0.973875     0.696364                   55.0
#  24          0.838875     0.224691     0.874785                   40.0
#  25          0.899655     0.917430     0.664199                   34.0
#  26          0.757296     0.850432     0.740854                   50.0
#  27          0.884760     0.129202     0.834219                   37.0
#  28          0.859479     0.733560     0.736777                   39.0
#  29          0.976330     0.944322     0.591898                   19.0
#
#      rank_proba_1_XGB  rank_proba_1_MLP  consensus_score
#  0                2.0               6.0         3.333333
#  1                4.0              11.0         5.333333
#  2                7.0               2.0         5.666667
#  3                6.0              14.0         8.333333
#  4                3.0              13.0         8.666667
#  5               16.0               5.0         9.000000
#  6                1.0              16.0         9.666667
#  7               17.0               7.0        11.666667
#  8               29.0               9.0        13.666667
#  9               13.0              25.0        15.000000
#  10               5.0              31.0        17.666667
#  11              34.0               4.0        19.333333
#  12              12.0              15.0        19.333333
#  13              23.0              35.0        20.666667
#  14              10.0              22.0        22.333333
#  15              14.0              38.0        22.666667
#  16              21.0              34.0        23.000000
#  17              43.0              10.0        25.666667
#  18              11.0              56.0        26.666667
#  19              35.0              21.0        28.000000
#  20              24.0              53.0        31.666667
#  21              18.0              43.0        32.333333
#  22              38.0              41.0        35.333333
#  23               8.0              44.0        35.666667
#  24              72.0               1.0        37.666667
#  25              20.0              60.0        38.000000
#  26              41.0              27.0        39.333333
#  27              82.0               3.0        40.666667
#  28              56.0              29.0        41.333333
#  29              15.0              94.0        42.666667  ,
#      consensus_rank                      Player     Season       Team Role  \
#  0                1               Adrien Rabiot  2018-2019  Paris S-G   RM
#  1                2               Adrien Rabiot  2017-2018  Paris S-G   RM
#  2                3               Yves Bissouma  2017-2018      Lille   DM
#  3                4             Tanguy Ndombele  2018-2019       Lyon   CM
#  4                5             Leandro Paredes  2020-2021  Paris S-G   DM
#  5                6         Aurélien Tchouaméni  2021-2022     Monaco   DM
#  6                7             Khéphren Thuram  2021-2022       Nice   CM
#  7                8              Marco Verratti  2018-2019  Paris S-G   CM
#  8                9              Marco Verratti  2021-2022  Paris S-G   CM
#  9               10              Marco Verratti  2019-2020  Paris S-G   CM
#  10              11             Tanguy Ndombele  2017-2018    2 Teams   CM
#  11              12                  Marquinhos  2018-2019  Paris S-G   DM
#  12              13                     Fabinho  2017-2018     Monaco   CM
#  13              14             Ibrahim Sangaré  2018-2019   Toulouse   DM
#  14              15                  Marquinhos  2019-2020  Paris S-G   DM
#  15              16             Leandro Paredes  2019-2020  Paris S-G   DM
#  16              17                Maxime Lopez  2018-2019  Marseille   CM
#  17              18            Valentin Rongier  2021-2022  Marseille   CM
#  18              19              Marco Verratti  2017-2018  Paris S-G   CM
#  19              20             Leandro Paredes  2021-2022  Paris S-G   DM
#  20              21              Marco Verratti  2020-2021  Paris S-G   CM
#  21              22                Maxime Lopez  2017-2018  Marseille   CM
#  22              23              Renato Sanches  2020-2021      Lille   CM
#  23              24              Renato Sanches  2021-2022      Lille   CM
#  24              25             Khéphren Thuram  2020-2021       Nice   CM
#  25              26  Andre-Frank Zambo Anguissa  2017-2018  Marseille   DM
#  26              27                Mario Lemina  2021-2022       Nice   DM
#  27              28         Aurélien Tchouaméni  2020-2021     Monaco   DM
#  28              29             Ibrahim Sangaré  2019-2020   Toulouse   DM
#  29              30             Youssouf Fofana  2021-2022     Monaco   DM
#
#      proba_1_Logistic  proba_1_XGB  proba_1_MLP  rank_proba_1_Logistic  \
#  0           0.986415     0.998532     0.982584                    1.0
#  1           0.942311     0.998202     0.963588                    4.0
#  2           0.926517     0.999650     0.964569                    7.0
#  3           0.937956     0.997112     0.938561                    6.0
#  4           0.896870     0.995881     0.944773                   12.0
#  5           0.878508     0.997266     0.916978                   13.0
#  6           0.848861     0.998106     0.918501                   19.0
#  7           0.948831     0.985624     0.911947                    3.0
#  8           0.917267     0.991664     0.879387                    8.0
#  9           0.942064     0.978908     0.916667                    5.0
#  10          0.864490     0.985942     0.885672                   14.0
#  11          0.858575     0.985467     0.903889                   15.0
#  12          0.818329     0.997452     0.818997                   23.0
#  13          0.777858     0.994606     0.858689                   26.0
#  14          0.849299     0.983302     0.875663                   18.0
#  15          0.898483     0.980078     0.849279                   11.0
#  16          0.831738     0.982398     0.883334                   21.0
#  17          0.785902     0.994386     0.832971                   25.0
#  18          0.973195     0.960896     0.946266                    2.0
#  19          0.838467     0.986525     0.831404                   20.0
#  20          0.910230     0.973351     0.880851                   10.0
#  21          0.856122     0.980317     0.822180                   16.0
#  22          0.792856     0.987637     0.775741                   24.0
#  23          0.851453     0.980261     0.794927                   17.0
#  24          0.761670     0.982752     0.869039                   30.0
#  25          0.760345     0.987109     0.752362                   31.0
#  26          0.709103     0.995780     0.642433                   38.0
#  27          0.698794     0.989376     0.761773                   43.0
#  28          0.697251     0.990319     0.681955                   44.0
#  29          0.714209     0.976735     0.762375                   35.0
#
#      rank_proba_1_XGB  rank_proba_1_MLP  consensus_score
#  0                2.0               1.0         1.333333
#  1                3.0               3.0         3.333333
#  2                1.0               2.0         3.333333
#  3                7.0               6.0         6.333333
#  4                8.0               5.0         8.333333
#  5                6.0               8.0         9.000000
#  6                4.0               7.0        10.000000
#  7               19.0              10.0        10.666667
#  8               12.0              15.0        11.666667
#  9               28.0               9.0        14.000000
#  10              18.0              12.0        14.666667
#  11              20.0              11.0        15.333333
#  12               5.0              24.0        17.333333
#  13              10.0              18.0        18.000000
#  14              21.0              16.0        18.333333
#  15              26.0              19.0        18.666667
#  16              23.0              13.0        19.000000
#  17              11.0              21.0        19.000000
#  18              52.0               4.0        19.333333
#  19              17.0              22.0        19.666667
#  20              39.0              14.0        21.000000
#  21              24.0              23.0        21.000000
#  22              15.0              28.0        22.333333
#  23              25.0              26.0        22.666667
#  24              22.0              17.0        23.000000
#  25              16.0              33.0        26.666667
#  26               9.0              41.0        29.333333
#  27              14.0              31.0        29.333333
#  28              13.0              38.0        31.666667
#  29              31.0              30.0        32.000000  )

# %%
Xtr_off, Xte_off, ytr_off, yte_off = make_train_test(off_mid, FEATURES_OFF, TARGET, test_size=0.25, random_state=42)
Xtr_def, Xte_def, ytr_def, yte_def = make_train_test(def_mid, FEATURES_DEF, TARGET, test_size=0.25, random_state=42)


off_log.fit(Xtr_off, ytr_off)
off_xgb.fit(Xtr_off, ytr_off)
off_mlp.fit(Xtr_off, ytr_off)

def_log.fit(Xtr_def, ytr_def)
def_xgb.fit(Xtr_def, ytr_def)
def_mlp.fit(Xtr_def, ytr_def)
# Out:
# C:\Users\jsava\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\jsava\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler()),
#                 ('clf',
#                  MLPClassifier(activation='tanh', alpha=1e-05,
#                                early_stopping=True, hidden_layer_sizes=(64, 32),
#                                max_iter=4000, n_iter_no_change=20,
#                                random_state=42))])

# %%
OFF_BG = Xtr_off.sample(min(120, len(Xtr_off)), random_state=42)
OFF_EX = Xte_off.sample(min(120, len(Xte_off)), random_state=42)

DEF_BG = Xtr_def.sample(min(120, len(Xtr_def)), random_state=42)
DEF_EX = Xte_def.sample(min(120, len(Xte_def)), random_state=42)

print("OFF MID Logistic SHAP")
_ = shap_for_logistic(off_log, OFF_BG, OFF_EX, FEATURES_OFF, max_display=20)

print("OFF MID XGB SHAP")
_ = shap_for_xgb(off_xgb, OFF_BG, OFF_EX, FEATURES_OFF, max_display=20)

print("DEF MID Logistic SHAP")
_ = shap_for_logistic(def_log, DEF_BG, DEF_EX, FEATURES_DEF, max_display=20)

print("DEF MID XGB SHAP")
_ = shap_for_xgb(def_xgb, DEF_BG, DEF_EX, FEATURES_DEF, max_display=20)
# Out:
# OFF MID Logistic SHAP
# OFF MID XGB SHAP
# DEF MID Logistic SHAP
# DEF MID XGB SHAP

# %%
def shap_summary_bar(
    shap_values,
    feature_names,
    top_k=20,
    title="SHAP summary: average impact on model output"
):
    

    mean_abs_shap = np.abs(shap_values).mean(axis=0)

    df = (
        pd.DataFrame({
            "feature": feature_names,
            "mean_abs_shap": mean_abs_shap
        })
        .sort_values("mean_abs_shap", ascending=False)
        .head(top_k)
    )

    plt.figure(figsize=(8, 5))
    plt.barh(df["feature"][::-1], df["mean_abs_shap"][::-1])
    plt.xlabel("Mean |SHAP value| (average impact on model output)")
    plt.title(title)
    plt.tight_layout()
    plt.show()

    return df

# %%
shap_off_log = shap_for_logistic(
    off_log,
    OFF_BG,
    OFF_EX,
    FEATURES_OFF,
    max_display=20
)

shap_summary_bar(
    shap_off_log,
    FEATURES_OFF,
    top_k=20,
    title="OFF MID Logistic – SHAP average impact"
)
# Out:
#                        feature  mean_abs_shap
# 20          PassLive_lead_goal       1.316984
# 10        Passes_completition%       1.064688
# 32     Passes_behind_defenders       0.994188
# 0                          Age       0.959226
# 39             Touches_Def_3rd       0.894710
# 31              Dead_ball_pass       0.816277
# 6                     Shot_/90       0.745023
# 33                Swing_passes       0.716067
# 16             PrgDist_Carries       0.705736
# 23                Aerials_Won%       0.597657
# 7       Goals_perShot_onTarget       0.561305
# 12      Crosses_into18yard_box       0.547858
# 21       Shot_creating_actions       0.532349
# 38             Touches_Def_Pen       0.517451
# 9             Passes_completed       0.517128
# 28               Blocking_ball       0.498962
# 42             Touches_Att_Pen       0.472387
# 29               Interceptions       0.421477
# 22  PassLive_lead_shot_attempt       0.365785
# 8              Shots_onTarget%       0.315567

# %%
shap_off_xgb = shap_for_xgb(
    off_xgb,
    OFF_BG,
    OFF_EX,
    FEATURES_OFF,
    max_display=20
)

shap_summary_bar(
    shap_off_xgb,
    FEATURES_OFF,
    top_k=20,
    title="OFF MID XGBoost – SHAP average impact"
)
# Out:
#                     feature  mean_abs_shap
# 7    Goals_perShot_onTarget       0.783889
# 0                       Age       0.699209
# 39          Touches_Def_3rd       0.698239
# 20       PassLive_lead_goal       0.619469
# 32  Passes_behind_defenders       0.396898
# 23             Aerials_Won%       0.347961
# 42          Touches_Att_Pen       0.337320
# 41          Touches_Att_3rd       0.283846
# 40          Touches_Mid_3rd       0.250728
# 31           Dead_ball_pass       0.229128
# 6                  Shot_/90       0.212103
# 34                  Crosses       0.210056
# 33             Swing_passes       0.207431
# 1                    Assist       0.185371
# 29            Interceptions       0.180447
# 37           Succ_Takes_on%       0.178476
# 9          Passes_completed       0.158165
# 38          Touches_Def_Pen       0.145558
# 28            Blocking_ball       0.138166
# 13       Progressive_passes       0.131943

# %%
shap_def_log = shap_for_logistic(
    def_log,
    DEF_BG,
    DEF_EX,
    FEATURES_DEF,
    max_display=20
)

shap_summary_bar(
    shap_def_log,
    FEATURES_DEF,
    top_k=20,
    title="DEF MID Logistic – SHAP average impact"
)
# Out:
#                        feature  mean_abs_shap
# 0                          Age       0.121656
# 20             TotDist_Carries       0.118808
# 16    TotDist_completed_passes       0.114747
# 42     Passes_behind_defenders       0.105410
# 4               Non_penalty_xG       0.104462
# 21             PrgDist_Carries       0.095412
# 31                Aerials_Won%       0.084598
# 39             Tackles_+Interc       0.081332
# 15          Progressive_passes       0.077957
# 28          PassLive_lead_goal       0.065555
# 44                     Crosses       0.063300
# 8                     Shot_/90       0.062127
# 23    Carries_into_final_third       0.059889
# 29       Shot_creating_actions       0.056594
# 30  PassLive_lead_shot_attempt       0.056205
# 38               Interceptions       0.055173
# 19            Long_passes_Cmp%       0.050605
# 14      Crosses_into18yard_box       0.048965
# 9       Goals_perShot_onTarget       0.048367
# 35  Lost_challange_drib_player       0.044514

# %%
shap_def_xgb = shap_for_xgb(
    def_xgb,
    DEF_BG,
    DEF_EX,
    FEATURES_DEF,
    max_display=20
)

shap_summary_bar(
    shap_def_xgb,
    FEATURES_DEF,
    top_k=20,
    title="DEF MID XGBoost – SHAP average impact"
)
# Out:
#                        feature  mean_abs_shap
# 16    TotDist_completed_passes       0.813651
# 0                          Age       0.582611
# 42     Passes_behind_defenders       0.558602
# 31                Aerials_Won%       0.494084
# 23    Carries_into_final_third       0.477080
# 47             Touches_Att_Pen       0.459346
# 21             PrgDist_Carries       0.446311
# 20             TotDist_Carries       0.417116
# 33                 Fouls_drawn       0.415193
# 14      Crosses_into18yard_box       0.411155
# 8                     Shot_/90       0.342309
# 43                Swing_passes       0.338528
# 44                     Crosses       0.328794
# 19            Long_passes_Cmp%       0.323451
# 39             Tackles_+Interc       0.321685
# 11             Shots_onTarget%       0.310152
# 35  Lost_challange_drib_player       0.305208
# 28          PassLive_lead_goal       0.277582
# 18       Attempted_long_passes       0.273589
# 36               Blocking_ball       0.246875

# %%
# Permutation importance tables

# OFF MID
off_log_pi_auc = permutation_importance_table(off_log, Xte_off, yte_off, FEATURES_OFF, scoring="roc_auc", n_repeats=30)
off_xgb_pi_auc = permutation_importance_table(off_xgb, Xte_off, yte_off, FEATURES_OFF, scoring="roc_auc", n_repeats=30)
off_mlp_pi_auc = permutation_importance_table(off_mlp, Xte_off, yte_off, FEATURES_OFF, scoring="roc_auc", n_repeats=30)

off_log_pi_ndcg = permutation_importance_table(off_log, Xte_off, yte_off, FEATURES_OFF, scoring=ndcg20_scorer, n_repeats=30)
off_xgb_pi_ndcg = permutation_importance_table(off_xgb, Xte_off, yte_off, FEATURES_OFF, scoring=ndcg20_scorer, n_repeats=30)
off_mlp_pi_ndcg = permutation_importance_table(off_mlp, Xte_off, yte_off, FEATURES_OFF, scoring=ndcg20_scorer, n_repeats=30)

# DEF MID
def_log_pi_auc = permutation_importance_table(def_log, Xte_def, yte_def, FEATURES_DEF, scoring="roc_auc", n_repeats=30)
def_xgb_pi_auc = permutation_importance_table(def_xgb, Xte_def, yte_def, FEATURES_DEF, scoring="roc_auc", n_repeats=30)
def_mlp_pi_auc = permutation_importance_table(def_mlp, Xte_def, yte_def, FEATURES_DEF, scoring="roc_auc", n_repeats=30)

def_log_pi_ndcg = permutation_importance_table(def_log, Xte_def, yte_def, FEATURES_DEF, scoring=ndcg20_scorer, n_repeats=30)
def_xgb_pi_ndcg = permutation_importance_table(def_xgb, Xte_def, yte_def, FEATURES_DEF, scoring=ndcg20_scorer, n_repeats=30)
def_mlp_pi_ndcg = permutation_importance_table(def_mlp, Xte_def, yte_def, FEATURES_DEF, scoring=ndcg20_scorer, n_repeats=30)

# Save
off_log_pi_auc.to_csv("OFF_MID_logistic_perm_auc.csv", index=False)
off_xgb_pi_auc.to_csv("OFF_MID_xgb_perm_auc.csv", index=False)
off_mlp_pi_auc.to_csv("OFF_MID_mlp_perm_auc.csv", index=False)

off_log_pi_ndcg.to_csv("OFF_MID_logistic_perm_ndcg20.csv", index=False)
off_xgb_pi_ndcg.to_csv("OFF_MID_xgb_perm_ndcg20.csv", index=False)
off_mlp_pi_ndcg.to_csv("OFF_MID_mlp_perm_ndcg20.csv", index=False)

def_log_pi_auc.to_csv("DEF_MID_logistic_perm_auc.csv", index=False)
def_xgb_pi_auc.to_csv("DEF_MID_xgb_perm_auc.csv", index=False)
def_mlp_pi_auc.to_csv("DEF_MID_mlp_perm_auc.csv", index=False)

def_log_pi_ndcg.to_csv("DEF_MID_logistic_perm_ndcg20.csv", index=False)
def_xgb_pi_ndcg.to_csv("DEF_MID_xgb_perm_ndcg20.csv", index=False)
def_mlp_pi_ndcg.to_csv("DEF_MID_mlp_perm_ndcg20.csv", index=False)


off_log_pi_ndcg.head(15), off_xgb_pi_ndcg.head(15), off_mlp_pi_ndcg.head(15), def_log_pi_ndcg.head(15), def_xgb_pi_ndcg.head(15), def_mlp_pi_ndcg.head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 4
#       1 # Permutation importance tables
#       2
#       3 # OFF MID
# ----> 4 off_log_pi_auc = permutation_importance_table(off_log, Xte_off, yte_off, FEATURES_OFF, scoring="roc_auc", n_repeats=30)
#       5 off_xgb_pi_auc = permutation_importance_table(off_xgb, Xte_off, yte_off, FEATURES_OFF, scoring="roc_auc", n_repeats=30)
#       6 off_mlp_pi_auc = permutation_importance_table(off_mlp, Xte_off, yte_off, FEATURES_OFF, scoring="roc_auc", n_repeats=30)
#
# Cell In[75], line 244, in permutation_importance_table(model, X_test, y_test, feature_names, scoring, n_repeats, random_state)
#     239 def permutation_importance_table(model, X_test, y_test, feature_names, scoring, n_repeats=20, random_state=42):
#     240     """
#     241     Returns dataframe with mean and std permutation importance.
#     242
#     243     """
# --> 244     result = permutation_importance(
#     245         model, X_test, y_test,
#     246         scoring=scoring,
#     247         n_repeats=n_repeats,
#     248         random_state=random_state,
#     249         n_jobs=-1
#     250     )
#     252     imp = pd.DataFrame({
#     253         "feature": feature_names,
#     254         "importance_mean": result.importances_mean,
#     255         "importance_std": result.importances_std
#     256     }).sort_values("importance_mean", ascending=False).reset_index(drop=True)
#     258     return imp
#
# NameError: name 'permutation_importance' is not defined

# %%
def plot_top_perm(imp_df, title, top_n=15):
    top = imp_df.head(top_n).iloc[::-1]
    plt.figure()
    plt.barh(top["feature"], top["importance_mean"])
    plt.title(title)
    plt.xlabel("Permutation importance")
    plt.tight_layout()
    plt.show()

plot_top_perm(off_log_pi_ndcg, "OFF MID Logistic, permutation importance using NDCG@20")
plot_top_perm(off_xgb_pi_ndcg, "OFF MID XGB, permutation importance using NDCG@20")
plot_top_perm(off_mlp_pi_ndcg, "OFF MID MLP, permutation importance using NDCG@20")

plot_top_perm(def_log_pi_ndcg, "DEF MID Logistic, permutation importance using NDCG@20")
plot_top_perm(def_xgb_pi_ndcg, "DEF MID XGB, permutation importance using NDCG@20")
plot_top_perm(def_mlp_pi_ndcg, "DEF MID MLP, permutation importance using NDCG@20")
